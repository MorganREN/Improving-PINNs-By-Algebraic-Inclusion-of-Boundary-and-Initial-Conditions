# %% [markdown]
# Consider the following Poisson equation with Dirichlet boundary condition over a bounded domain $\Omega\subset\mathbb{R}^d$
# \begin{equation}
# \begin{cases}
# -\Delta u(x) = f(x), & \;\text{in} \;\Omega,\\
# u(x) = g(x), & \; \text{on} \; \partial\Omega,
# \end{cases}
# \end{equation}
# where $f, g$ are given functions.
# Denote $u(x;\theta)$   the approximate NN solution with the set of parameters  $\theta$  in the NN. The collection of all $u(x;\theta)$ is used as the trial space.

# %% [markdown]
# ## 1. Setup

# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import LogNorm
import math
from math import *
import time
import copy
import itertools
from tqdm import *
import seaborn as sns
import matplotlib.pyplot as plt
import random
import pickle

torch.set_default_tensor_type('torch.DoubleTensor')

# %% [markdown]
# ## 2. Hyperparameter

# %%
dimension_list = [50]
net_width_list = [50]

# %% [markdown]
# ## 3. Neural Architecture

# %%
# %%
# activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# build ResNet with one blocks
class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(Net,self).__init__()
        self.layer1 = torch.nn.Linear(input_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer3 = torch.nn.Linear(layer_width, layer_width)
        self.layer4 = torch.nn.Linear(layer_width, 1)
        self.initialize_weights()
    def forward(self,x):
        y = activation(self.layer1(x))
        y = activation(self.layer3(activation(self.layer2(y)))) # residual block 1
        output = self.layer4(y)
        return output
    def initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight.data)
                if m.bias is not None:
                    m.bias.data.zero_()
    def print_network(self):
        num_params = 0
        for param in self.parameters():
            num_params += param.numel()
        # print(self)
        print('Total number of parameters: %d' % num_params)

# %%
#net = Net(input_width,layer_width)

# %% [markdown]
# The experiment define the neural network $\mathcal{N}: \mathbb{R}^d \rightarrow \mathbb{R}$ as follows:
# \begin{equation}
# \mathcal{N}(\vec{x}) := \sigma(A_4\cdot\sigma(A_3\cdot\sigma (A_2\cdot\sigma (A_1))))
# \end{equation}
# where ${\rm A}_{1}, {\rm A}_2, {\rm A}_{3},$ and ${\rm A}_{4}$ are fully-connected layers with the activation function $\sigma$. The number of parameters in $\mathcal{N}$ is given by $p = (d \cdot {\rm width} + {\rm width}) + 2({\rm width} \cdot {\rm width} + {\rm width}) + ({\rm width} \cdot 1 + 1) = 2 \cdot {\rm width}^2 + (4 + d) \cdot {\rm width} + 1$.
#
# note: there are $p$ parameters need to be trained in total in ${\rm N}(x)$

# %% [markdown]
# ## 4. Training Setup

# %% [markdown]
# ### 4.1 Define the exact solution
#
# $$[0,1]^d{\ni}{\vec x} {↦} u(x) = {∏}_{i=1}^d{\sin}(π{\vec x}_i) {∈} {\mathbb R}$$

# %%
def u_ex(x, dimension):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    return u_temp.reshape([x.size()[0], 1])

# %% [markdown]
# ### 4.2 Define the $f(x)$
# $$[0,1]^d{\ni }{\vec x} {↦} f({\vec x}) = dπ^2{∏}_{i=1}^d\sin(πx_i){∈}{\mathbb R}$$

# %%
def f(x, dimension):
    temp = 1.0
    for i in range(dimension):
        temp = temp * torch.sin(pi*x[:, i])
    u_temp = 1.0 * temp
    f_temp = dimension * pi**2 * u_temp
    return f_temp.reshape([x.size()[0], 1])

# %% [markdown]
# ### 4.3 Generate sample

# %%
def generate_sample(data_size, dimension):
    sample_temp = torch.rand(data_size, dimension)
    return sample_temp

# %% [markdown]
# ### 4.4 Build the model
#
# \begin{equation}
# model = u(x;\theta) =    NN(x;\theta).
# \end{equation}
# where $NN(x;\theta)$ is a function represented by a neural network.

# %%
def model(x):
    x_temp = x
    model_u_temp = net(x)
    return model_u_temp.reshape([x.size()[0], 1])

# %% [markdown]
# ### 4.5 Define Loss function（energy）
# \begin{equation}
# \mathcal{L}{energy}(\hat{u}) = \frac{1}{N} \sum_{i=1}^{N} \left[ \frac{1}{2} \left\vert \nabla \hat{u}(\vec x_i; \theta) \right\vert^2 - f(x_i) \hat{u}(\vec x_i; \theta) \right] + \frac{\beta}{M} \sum_{j=1}^{M} \hat{u}(\vec x_j; \theta)^2 I(\vec x_j \in \partial \Omega), \quad {\vec x} \in [0,1]^d
# \end{equation}
# where $N$ is the total number of mesh points used in the training dataset and $M$ is the number of points on the boundary of the domain $\Omega$, the index $i$ is used to iterate over the mesh points, while the index $j$ is used to iterate over the boundary points. $I$ is an indicative function, i.e., $I=1$ when the condition of the parentheses holds, otherwise it is 0. \\
# note:  for `loss_energy = torch.sum(0.5 * grad_u_sq  - f(x) * u_hat)  / len(x)`, it divides the length of x because the length of $Ω$ is 1

# %%
def loss_function_energy(x, dimension, dimension_sample_size, beta):
    u_hat = model(x)
    grad_u_hat = torch.autograd.grad(outputs=u_hat, inputs=x, grad_outputs=torch.ones(u_hat.shape), create_graph=True)
    grad_u_sq = ((grad_u_hat[0] ** 2).sum(1)).reshape([len(grad_u_hat[0]), 1])
    part_1 = torch.sum(0.5 * grad_u_sq - f(x, dimension) * u_hat) / len(x)

    boundary_loss = torch.zeros(1)
    boundary_sample_size = dimension_sample_size * 2 * dimension
    boundary_sample = generate_sample(boundary_sample_size, dimension)

    for i in range(dimension):
        # sample k points on the i-th face with the i-th coordinate fixed to 1
        for j in range(dimension_sample_size):
            boundary_sample[i*2*dimension_sample_size + j, i] = 1.0
            boundary_sample[i*2*dimension_sample_size + j, :i] = torch.rand(i)
            boundary_sample[i*2*dimension_sample_size + j, i+1:] = torch.rand(dimension-i-1)
            
        # sample k points on the i-th face with the i-th coordinate fixed to 0
        for j in range(dimension_sample_size):
            boundary_sample[(i+1)*2*dimension_sample_size - dimension_sample_size + j, i] = 0.0
            boundary_sample[(i+1)*2*dimension_sample_size - dimension_sample_size + j, :i] = torch.rand(i)
            boundary_sample[(i+1)*2*dimension_sample_size - dimension_sample_size + j, i+1:] = torch.rand(dimension-i-1)

    boundary_loss = beta * torch.sum((model(boundary_sample)) ** 2) / boundary_sample_size
    loss_energy = part_1 + boundary_loss

    return loss_energy

# %% [markdown]
# ### 4.6 Define Fractional Error
#
# $${\rm error} = \frac{\lVert \hat u - u \lVert _2^2}{\lVert u \lVert _2^2}$$

# %%
def fractional_error(x):
  u_hat = model(x)
  u = u_ex(x, input_width)
  upper = torch.square((u_hat - u).norm(2))
  lower = torch.square(u.norm(2))
  return torch.divide(upper, lower)

# %% [markdown]
# ## 5. Doing The Training

# %%
random.seed(100)
test_sample_size = 10000
batch_size = 2048
epoch = 7000
beta = 10000

dimension_sample_size = 200

# %%
energy_loss_mat_e = np.zeros((len(net_width_list), len(dimension_list)))
energy_fractional_error = np.zeros((len(net_width_list), len(dimension_list)))
all_data = []
epoch_data = []
loss_record_e = []
error_record_e = []
loss_epoch_e = []
error_epoch_e = []

for dim_item in range(len(dimension_list)):
    input_width = dimension_list[dim_item]
    test_sample = generate_sample(test_sample_size, input_width)
    for width_item in range(len(net_width_list)):
        print("The current width:"+ str(net_width_list[width_item]))
        print("The current dimensions:"+ str(dimension_list[dim_item]))
        layer_width = net_width_list[width_item]
        net = DeepRitzNet(input_width, layer_width)
        optimizer = optim.Adam(net.parameters(), lr=0.0001)
        data_size = batch_size
        loss_epoch = []
        error_epoch = []
        for i in range(epoch):
            optimizer.zero_grad()
            x = generate_sample(data_size, input_width)
            x.requires_grad = True
            loss = loss_function_energy(x, input_width, dimension_sample_size, beta)
            loss.backward()
            optimizer.step()
            torch.cuda.empty_cache()

            test_sample_fractional_error = fractional_error(test_sample)
            print("dimension = {}, width = {},  epoch = {}, loss = {}, fractional_error = {} ".format(
                input_width, layer_width, i, loss.data[0].numpy(), test_sample_fractional_error
            ))
            loss_epoch.append(float(loss))
            error_epoch.append(float(test_sample_fractional_error))

        test_sample_fractional_error = fractional_error(test_sample)
        energy_fractional_error[width_item, dim_item] = float(test_sample_fractional_error)
        energy_loss_mat_e[width_item, dim_item] = float(loss)
        loss_record_e.append(float(loss))
        error_record_e.append(float(test_sample_fractional_error))
        loss_epoch_e.append(loss_epoch)
        error_epoch_e.append(error_epoch)

all_data.append(loss_record_e)
all_data.append(error_record_e)
all_data.append(net_width_list)
epoch_data.append(loss_epoch_e)
epoch_data.append(error_epoch_e)

with open('loss_record_all.pkl', 'wb') as f:
     pickle.dump(all_data, f)

with open('epoch_record.pkl', 'wb') as f:
     pickle.dump(epoch_data, f)
# Out:
# The current width:50
# The current dimensions:50
# dimension = 50, width = 50,  epoch = 0, loss = 1132.5924573664706, fractional_error = 8886.47853946698
# dimension = 50, width = 50,  epoch = 1, loss = 993.9747673952464, fractional_error = 8350.822773933398
# dimension = 50, width = 50,  epoch = 2, loss = 880.6332249353645, fractional_error = 7824.40599432811
# dimension = 50, width = 50,  epoch = 3, loss = 782.517490165248, fractional_error = 7308.604998416982
# dimension = 50, width = 50,  epoch = 4, loss = 662.6020815418027, fractional_error = 6806.058756061048
# dimension = 50, width = 50,  epoch = 5, loss = 586.5785057384228, fractional_error = 6318.0967320652635
# dimension = 50, width = 50,  epoch = 6, loss = 500.3061696327754, fractional_error = 5847.383016785687
# dimension = 50, width = 50,  epoch = 7, loss = 433.61729510974703, fractional_error = 5395.514732508158
# dimension = 50, width = 50,  epoch = 8, loss = 369.8031822030646, fractional_error = 4964.118160394049
# dimension = 50, width = 50,  epoch = 9, loss = 315.5360092854389, fractional_error = 4554.768465385269
# dimension = 50, width = 50,  epoch = 10, loss = 269.86236743876566, fractional_error = 4168.384850443405
# dimension = 50, width = 50,  epoch = 11, loss = 222.7685184122947, fractional_error = 3806.2932624598584
# dimension = 50, width = 50,  epoch = 12, loss = 184.51614138143938, fractional_error = 3469.489670024801
# dimension = 50, width = 50,  epoch = 13, loss = 155.74508475704943, fractional_error = 3157.9924487907615
# dimension = 50, width = 50,  epoch = 14, loss = 123.63177047342883, fractional_error = 2871.9836790516365
# dimension = 50, width = 50,  epoch = 15, loss = 102.98435060931212, fractional_error = 2610.9689979176037
# dimension = 50, width = 50,  epoch = 16, loss = 88.62891906682447, fractional_error = 2373.747380742507
# dimension = 50, width = 50,  epoch = 17, loss = 74.25272771882916, fractional_error = 2158.941216427113
# dimension = 50, width = 50,  epoch = 18, loss = 61.34836461816277, fractional_error = 1965.259431122278
# dimension = 50, width = 50,  epoch = 19, loss = 46.497664463174694, fractional_error = 1791.6941124247007
# dimension = 50, width = 50,  epoch = 20, loss = 41.872751843002604, fractional_error = 1636.1093234665957
# dimension = 50, width = 50,  epoch = 21, loss = 35.854097571389666, fractional_error = 1497.0245624785266
# dimension = 50, width = 50,  epoch = 22, loss = 27.811218816166317, fractional_error = 1373.1404713829156
# dimension = 50, width = 50,  epoch = 23, loss = 25.659637121940783, fractional_error = 1262.666001858846
# dimension = 50, width = 50,  epoch = 24, loss = 21.339709582482524, fractional_error = 1164.2058709387866
# dimension = 50, width = 50,  epoch = 25, loss = 16.943830250867528, fractional_error = 1076.6559596791367
# dimension = 50, width = 50,  epoch = 26, loss = 14.574415390234538, fractional_error = 998.7666085718239
# dimension = 50, width = 50,  epoch = 27, loss = 13.283297299584769, fractional_error = 929.4282761430619
# dimension = 50, width = 50,  epoch = 28, loss = 10.540911260588743, fractional_error = 867.6494559664551
# dimension = 50, width = 50,  epoch = 29, loss = 10.254184185081932, fractional_error = 812.4195871353674
# dimension = 50, width = 50,  epoch = 30, loss = 8.909572251882215, fractional_error = 763.0020603164543
# dimension = 50, width = 50,  epoch = 31, loss = 7.79256241906077, fractional_error = 718.7546676160046
# dimension = 50, width = 50,  epoch = 32, loss = 6.867212815964016, fractional_error = 679.107218330782
# dimension = 50, width = 50,  epoch = 33, loss = 5.60008991444933, fractional_error = 643.5556417035488
# dimension = 50, width = 50,  epoch = 34, loss = 5.532675482537339, fractional_error = 611.616157450118
# dimension = 50, width = 50,  epoch = 35, loss = 5.126246104372017, fractional_error = 582.8747716294005
# dimension = 50, width = 50,  epoch = 36, loss = 4.377020241879698, fractional_error = 557.0011923045172
# dimension = 50, width = 50,  epoch = 37, loss = 4.421308943618113, fractional_error = 533.6235691760099
# dimension = 50, width = 50,  epoch = 38, loss = 3.8519927428229663, fractional_error = 512.5001409567373
# dimension = 50, width = 50,  epoch = 39, loss = 3.876076651987184, fractional_error = 493.34632026463794
# dimension = 50, width = 50,  epoch = 40, loss = 3.4207034502142553, fractional_error = 475.9720777867064
# dimension = 50, width = 50,  epoch = 41, loss = 3.457291418119092, fractional_error = 460.17138757874557
# dimension = 50, width = 50,  epoch = 42, loss = 2.891512961279028, fractional_error = 445.7969872619407
# dimension = 50, width = 50,  epoch = 43, loss = 2.892483706441816, fractional_error = 432.67711855840406
# dimension = 50, width = 50,  epoch = 44, loss = 2.9197728101106666, fractional_error = 420.6562861961158
# dimension = 50, width = 50,  epoch = 45, loss = 2.6244492802847015, fractional_error = 409.61863677321196
# dimension = 50, width = 50,  epoch = 46, loss = 1.9992117190772356, fractional_error = 399.51501233427246
# dimension = 50, width = 50,  epoch = 47, loss = 2.2838778450602697, fractional_error = 390.22545887498245
# dimension = 50, width = 50,  epoch = 48, loss = 2.217987485039247, fractional_error = 381.65521849989665
# dimension = 50, width = 50,  epoch = 49, loss = 2.122470668599615, fractional_error = 373.73135640520786
# dimension = 50, width = 50,  epoch = 50, loss = 2.398665402414269, fractional_error = 366.3640199619708
# dimension = 50, width = 50,  epoch = 51, loss = 1.5570868863707068, fractional_error = 359.55925708374843
# dimension = 50, width = 50,  epoch = 52, loss = 1.9752245956870644, fractional_error = 353.21665985007417
# dimension = 50, width = 50,  epoch = 53, loss = 1.4319613617099023, fractional_error = 347.32524572318124
# dimension = 50, width = 50,  epoch = 54, loss = 1.7343979141337902, fractional_error = 341.8274039662014
# dimension = 50, width = 50,  epoch = 55, loss = 1.8137041586145588, fractional_error = 336.66516801508794
# dimension = 50, width = 50,  epoch = 56, loss = 2.021733506845045, fractional_error = 331.7930996045829
# dimension = 50, width = 50,  epoch = 57, loss = 1.2606903122659572, fractional_error = 327.23735848840255
# dimension = 50, width = 50,  epoch = 58, loss = 1.353660238076004, fractional_error = 322.962385117913
# dimension = 50, width = 50,  epoch = 59, loss = 1.6282295319681848, fractional_error = 318.921218524157
# dimension = 50, width = 50,  epoch = 60, loss = 1.3875383432128543, fractional_error = 315.1004961392428
# dimension = 50, width = 50,  epoch = 61, loss = 1.6632179408898304, fractional_error = 311.46116141977313
# dimension = 50, width = 50,  epoch = 62, loss = 1.3747550892433467, fractional_error = 308.0113549672285
# dimension = 50, width = 50,  epoch = 63, loss = 1.3505810475491935, fractional_error = 304.7296509982973
# dimension = 50, width = 50,  epoch = 64, loss = 1.4460210825618256, fractional_error = 301.59218060917857
# dimension = 50, width = 50,  epoch = 65, loss = 1.4505899366658102, fractional_error = 298.5899838295471
# dimension = 50, width = 50,  epoch = 66, loss = 1.3588545556193343, fractional_error = 295.7200640477167
# dimension = 50, width = 50,  epoch = 67, loss = 1.1928946365231183, fractional_error = 292.9803164972877
# dimension = 50, width = 50,  epoch = 68, loss = 1.2042578466954852, fractional_error = 290.358038000718
# dimension = 50, width = 50,  epoch = 69, loss = 1.4558000120810712, fractional_error = 287.82097313772175
# dimension = 50, width = 50,  epoch = 70, loss = 1.3064166251142417, fractional_error = 285.3735562367207
# dimension = 50, width = 50,  epoch = 71, loss = 1.0001361343486268, fractional_error = 283.03185481970934
# dimension = 50, width = 50,  epoch = 72, loss = 1.2198663701624723, fractional_error = 280.7553751697802
# dimension = 50, width = 50,  epoch = 73, loss = 1.155149617414368, fractional_error = 278.5581637432072
# dimension = 50, width = 50,  epoch = 74, loss = 1.054226077993397, fractional_error = 276.42752379567827
# dimension = 50, width = 50,  epoch = 75, loss = 0.865927509716609, fractional_error = 274.3751513096141
# dimension = 50, width = 50,  epoch = 76, loss = 1.2469784589813537, fractional_error = 272.36739745275577
# dimension = 50, width = 50,  epoch = 77, loss = 1.1332480736226682, fractional_error = 270.4050889131015
# dimension = 50, width = 50,  epoch = 78, loss = 1.0245738216607876, fractional_error = 268.48383543700123
# dimension = 50, width = 50,  epoch = 79, loss = 0.8670629012361053, fractional_error = 266.6311293906706
# dimension = 50, width = 50,  epoch = 80, loss = 1.0691244070215182, fractional_error = 264.81574405235096
# dimension = 50, width = 50,  epoch = 81, loss = 0.8067469040247316, fractional_error = 263.0599182767492
# dimension = 50, width = 50,  epoch = 82, loss = 1.188454237901805, fractional_error = 261.324782688927
# dimension = 50, width = 50,  epoch = 83, loss = 1.1632547500665829, fractional_error = 259.60192139554795
# dimension = 50, width = 50,  epoch = 84, loss = 0.9184560804494984, fractional_error = 257.92300764117584
# dimension = 50, width = 50,  epoch = 85, loss = 0.9984856491329931, fractional_error = 256.2857194935773
# dimension = 50, width = 50,  epoch = 86, loss = 0.8760021140194809, fractional_error = 254.68659342329735
# dimension = 50, width = 50,  epoch = 87, loss = 0.8858997678540071, fractional_error = 253.1165310902307
# dimension = 50, width = 50,  epoch = 88, loss = 0.848053047906859, fractional_error = 251.57929546225336
# dimension = 50, width = 50,  epoch = 89, loss = 1.0962760349132668, fractional_error = 250.05477598188406
# dimension = 50, width = 50,  epoch = 90, loss = 1.1375305708612384, fractional_error = 248.5421376452344
# dimension = 50, width = 50,  epoch = 91, loss = 0.8518880877901337, fractional_error = 247.0501742914897
# dimension = 50, width = 50,  epoch = 92, loss = 0.7262892703437047, fractional_error = 245.58778002639613
# dimension = 50, width = 50,  epoch = 93, loss = 0.8310481348597742, fractional_error = 244.14618807138746
# dimension = 50, width = 50,  epoch = 94, loss = 0.993359747195157, fractional_error = 242.71176655966966
# dimension = 50, width = 50,  epoch = 95, loss = 0.8447449471168644, fractional_error = 241.30461996211665
# dimension = 50, width = 50,  epoch = 96, loss = 0.8754096060772747, fractional_error = 239.90564494103236
# dimension = 50, width = 50,  epoch = 97, loss = 0.6971162269848822, fractional_error = 238.53951764745787
# dimension = 50, width = 50,  epoch = 98, loss = 0.7163565770806851, fractional_error = 237.20204378259032
# dimension = 50, width = 50,  epoch = 99, loss = 1.0545457851476254, fractional_error = 235.86782425586753
# dimension = 50, width = 50,  epoch = 100, loss = 0.7756558968213056, fractional_error = 234.55328442240645
# dimension = 50, width = 50,  epoch = 101, loss = 1.0726254822457588, fractional_error = 233.22251556779463
# dimension = 50, width = 50,  epoch = 102, loss = 0.7778225649711146, fractional_error = 231.91053456372993
# dimension = 50, width = 50,  epoch = 103, loss = 0.908231281261453, fractional_error = 230.60325256834832
# dimension = 50, width = 50,  epoch = 104, loss = 0.7372541953217981, fractional_error = 229.31385902382002
# dimension = 50, width = 50,  epoch = 105, loss = 0.6799053214825517, fractional_error = 228.05039557178193
# dimension = 50, width = 50,  epoch = 106, loss = 0.7048537383116126, fractional_error = 226.80565251643694
# dimension = 50, width = 50,  epoch = 107, loss = 0.902923409186265, fractional_error = 225.56370889280936
# dimension = 50, width = 50,  epoch = 108, loss = 0.8617542242707255, fractional_error = 224.3202399645273
# dimension = 50, width = 50,  epoch = 109, loss = 0.7379280800759564, fractional_error = 223.08907679849528
# dimension = 50, width = 50,  epoch = 110, loss = 0.8989626598135589, fractional_error = 221.85500069675976
# dimension = 50, width = 50,  epoch = 111, loss = 0.7218445160339745, fractional_error = 220.62968798851745
# dimension = 50, width = 50,  epoch = 112, loss = 0.623379075328053, fractional_error = 219.43001344540994
# dimension = 50, width = 50,  epoch = 113, loss = 0.6652948262731251, fractional_error = 218.2409378732243
# dimension = 50, width = 50,  epoch = 114, loss = 0.6623656946293346, fractional_error = 217.06994414717946
# dimension = 50, width = 50,  epoch = 115, loss = 0.7826629885372284, fractional_error = 215.90769539425216
# dimension = 50, width = 50,  epoch = 116, loss = 0.7694056907993273, fractional_error = 214.76001570997119
# dimension = 50, width = 50,  epoch = 117, loss = 0.9070302138583674, fractional_error = 213.61102718102367
# dimension = 50, width = 50,  epoch = 118, loss = 0.6721948004881937, fractional_error = 212.48273186562787
# dimension = 50, width = 50,  epoch = 119, loss = 0.8739652555538667, fractional_error = 211.33863849040148
# dimension = 50, width = 50,  epoch = 120, loss = 0.7237334188010139, fractional_error = 210.20820657983157
# dimension = 50, width = 50,  epoch = 121, loss = 0.570054676107829, fractional_error = 209.0985192526601
# dimension = 50, width = 50,  epoch = 122, loss = 0.9515886184400808, fractional_error = 207.96852068656472
# dimension = 50, width = 50,  epoch = 123, loss = 0.7952816157048966, fractional_error = 206.8396828714662
# dimension = 50, width = 50,  epoch = 124, loss = 0.8014527200580975, fractional_error = 205.71406442796476
# dimension = 50, width = 50,  epoch = 125, loss = 0.8047598489259316, fractional_error = 204.59363965932116
# dimension = 50, width = 50,  epoch = 126, loss = 0.6802679659736935, fractional_error = 203.49046274298055
# dimension = 50, width = 50,  epoch = 127, loss = 0.7205291741250167, fractional_error = 202.39190146116445
# dimension = 50, width = 50,  epoch = 128, loss = 0.651309340450851, fractional_error = 201.31140185862543
# dimension = 50, width = 50,  epoch = 129, loss = 0.47825295797057604, fractional_error = 200.25753890706656
# dimension = 50, width = 50,  epoch = 130, loss = 0.6161120924132204, fractional_error = 199.2122801496702
# dimension = 50, width = 50,  epoch = 131, loss = 0.560453849398399, fractional_error = 198.1821510003154
# dimension = 50, width = 50,  epoch = 132, loss = 0.5470808764556988, fractional_error = 197.16685259707685
# dimension = 50, width = 50,  epoch = 133, loss = 0.7464106867851124, fractional_error = 196.14929979436033
# dimension = 50, width = 50,  epoch = 134, loss = 0.5734864912607771, fractional_error = 195.14600718279934
# dimension = 50, width = 50,  epoch = 135, loss = 0.5555699648306983, fractional_error = 194.15679608483546
# dimension = 50, width = 50,  epoch = 136, loss = 0.5819030101960345, fractional_error = 193.17781652304257
# dimension = 50, width = 50,  epoch = 137, loss = 0.6269399302904918, fractional_error = 192.20441874231327
# dimension = 50, width = 50,  epoch = 138, loss = 0.7763439368736007, fractional_error = 191.22465061237736
# dimension = 50, width = 50,  epoch = 139, loss = 0.740435082587887, fractional_error = 190.2409034252789
# dimension = 50, width = 50,  epoch = 140, loss = 0.6730837900865387, fractional_error = 189.26520558098247
# dimension = 50, width = 50,  epoch = 141, loss = 0.6960071247009932, fractional_error = 188.28578234553757
# dimension = 50, width = 50,  epoch = 142, loss = 0.5237156943651937, fractional_error = 187.32162855257457
# dimension = 50, width = 50,  epoch = 143, loss = 0.43797550218148373, fractional_error = 186.381436806645
# dimension = 50, width = 50,  epoch = 144, loss = 0.36837681038745385, fractional_error = 185.4771126976026
# dimension = 50, width = 50,  epoch = 145, loss = 0.5332482322429419, fractional_error = 184.58291863184974
# dimension = 50, width = 50,  epoch = 146, loss = 0.6499099203779705, fractional_error = 183.67939731407444
# dimension = 50, width = 50,  epoch = 147, loss = 0.46891669239993106, fractional_error = 182.78505827942473
# dimension = 50, width = 50,  epoch = 148, loss = 0.6270801320954281, fractional_error = 181.88108575652134
# dimension = 50, width = 50,  epoch = 149, loss = 0.4125753075418184, fractional_error = 180.98917502780878
# dimension = 50, width = 50,  epoch = 150, loss = 0.3852949393934874, fractional_error = 180.11395930115742
# dimension = 50, width = 50,  epoch = 151, loss = 0.555590577532588, fractional_error = 179.24058964118495
# dimension = 50, width = 50,  epoch = 152, loss = 0.5081291744824386, fractional_error = 178.37331676089252
# dimension = 50, width = 50,  epoch = 153, loss = 0.43451435530952986, fractional_error = 177.51975465708813
# dimension = 50, width = 50,  epoch = 154, loss = 0.4788367222466848, fractional_error = 176.68033933005262
# dimension = 50, width = 50,  epoch = 155, loss = 0.4678090939204712, fractional_error = 175.84256870608007
# dimension = 50, width = 50,  epoch = 156, loss = 0.5054874760902048, fractional_error = 175.00921252470934
# dimension = 50, width = 50,  epoch = 157, loss = 0.43379644240436893, fractional_error = 174.18498768869338
# dimension = 50, width = 50,  epoch = 158, loss = 0.49023886122506344, fractional_error = 173.36379792825713
# dimension = 50, width = 50,  epoch = 159, loss = 0.5396358448709835, fractional_error = 172.54762260903786
# dimension = 50, width = 50,  epoch = 160, loss = 0.3898491077773918, fractional_error = 171.73714259750253
# dimension = 50, width = 50,  epoch = 161, loss = 0.38422429848788375, fractional_error = 170.93734166124224
# dimension = 50, width = 50,  epoch = 162, loss = 0.46318151128364266, fractional_error = 170.14712389285776
# dimension = 50, width = 50,  epoch = 163, loss = 0.4135729686786533, fractional_error = 169.36396804239556
# dimension = 50, width = 50,  epoch = 164, loss = 0.3379786068402192, fractional_error = 168.5960986491909
# dimension = 50, width = 50,  epoch = 165, loss = 0.41313518214613437, fractional_error = 167.8393673932683
# dimension = 50, width = 50,  epoch = 166, loss = 0.3975355508856743, fractional_error = 167.0912173055631
# dimension = 50, width = 50,  epoch = 167, loss = 0.5165744449259111, fractional_error = 166.33994984989923
# dimension = 50, width = 50,  epoch = 168, loss = 0.5027822584328919, fractional_error = 165.5831488691292
# dimension = 50, width = 50,  epoch = 169, loss = 0.4308971124034297, fractional_error = 164.83670228654006
# dimension = 50, width = 50,  epoch = 170, loss = 0.37886061298956186, fractional_error = 164.09552320245993
# dimension = 50, width = 50,  epoch = 171, loss = 0.4171005415940038, fractional_error = 163.34990504729936
# dimension = 50, width = 50,  epoch = 172, loss = 0.5149712999515097, fractional_error = 162.5989159705371
# dimension = 50, width = 50,  epoch = 173, loss = 0.4664311127611513, fractional_error = 161.84313114757956
# dimension = 50, width = 50,  epoch = 174, loss = 0.2906092186541458, fractional_error = 161.10633431250673
# dimension = 50, width = 50,  epoch = 175, loss = 0.42777830025287117, fractional_error = 160.37034403982196
# dimension = 50, width = 50,  epoch = 176, loss = 0.4353359184016527, fractional_error = 159.62779617815517
# dimension = 50, width = 50,  epoch = 177, loss = 0.5498720973785497, fractional_error = 158.87424143061554
# dimension = 50, width = 50,  epoch = 178, loss = 0.4005564500743182, fractional_error = 158.12731196617312
# dimension = 50, width = 50,  epoch = 179, loss = 0.3791242377512686, fractional_error = 157.38062776870342
# dimension = 50, width = 50,  epoch = 180, loss = 0.4416552929231359, fractional_error = 156.62963048588904
# dimension = 50, width = 50,  epoch = 181, loss = 0.37400629738125085, fractional_error = 155.88513758787502
# dimension = 50, width = 50,  epoch = 182, loss = 0.3105917298725287, fractional_error = 155.14071291324942
# dimension = 50, width = 50,  epoch = 183, loss = 0.3654381071713863, fractional_error = 154.40172366369262
# dimension = 50, width = 50,  epoch = 184, loss = 0.24042977760057185, fractional_error = 153.66414673281088
# dimension = 50, width = 50,  epoch = 185, loss = 0.401323113939459, fractional_error = 152.92490741664056
# dimension = 50, width = 50,  epoch = 186, loss = 0.5295275137272291, fractional_error = 152.17318416529932
# dimension = 50, width = 50,  epoch = 187, loss = 0.3306259157347685, fractional_error = 151.43157012799873
# dimension = 50, width = 50,  epoch = 188, loss = 0.34151907990685354, fractional_error = 150.69590971810848
# dimension = 50, width = 50,  epoch = 189, loss = 0.3560350527637914, fractional_error = 149.9667869786295
# dimension = 50, width = 50,  epoch = 190, loss = 0.39860406846852386, fractional_error = 149.2192459177513
# dimension = 50, width = 50,  epoch = 191, loss = 0.35591795183318514, fractional_error = 148.47903670122173
# dimension = 50, width = 50,  epoch = 192, loss = 0.4099661261748692, fractional_error = 147.74234858650564
# dimension = 50, width = 50,  epoch = 193, loss = 0.33919342573582584, fractional_error = 147.0152685838434
# dimension = 50, width = 50,  epoch = 194, loss = 0.41291855748776174, fractional_error = 146.2887522324319
# dimension = 50, width = 50,  epoch = 195, loss = 0.38631677953721605, fractional_error = 145.57152800240408
# dimension = 50, width = 50,  epoch = 196, loss = 0.434993245881469, fractional_error = 144.84815111679734
# dimension = 50, width = 50,  epoch = 197, loss = 0.4186099802286216, fractional_error = 144.11450128830708
# dimension = 50, width = 50,  epoch = 198, loss = 0.282723149261433, fractional_error = 143.38225441022237
# dimension = 50, width = 50,  epoch = 199, loss = 0.46125788904024284, fractional_error = 142.63204775346694
# dimension = 50, width = 50,  epoch = 200, loss = 0.19187821617648756, fractional_error = 141.89933352814438
# dimension = 50, width = 50,  epoch = 201, loss = 0.26991439113514637, fractional_error = 141.17544655790238
# dimension = 50, width = 50,  epoch = 202, loss = 0.2540583867728797, fractional_error = 140.45761184794537
# dimension = 50, width = 50,  epoch = 203, loss = 0.3765594841695646, fractional_error = 139.72417534900984
# dimension = 50, width = 50,  epoch = 204, loss = 0.35691180201393763, fractional_error = 138.98735853066376
# dimension = 50, width = 50,  epoch = 205, loss = 0.2857422119776365, fractional_error = 138.25581599726706
# dimension = 50, width = 50,  epoch = 206, loss = 0.3231296867826904, fractional_error = 137.52009168880377
# dimension = 50, width = 50,  epoch = 207, loss = 0.43646910938913364, fractional_error = 136.7711661293459
# dimension = 50, width = 50,  epoch = 208, loss = 0.34119777853956873, fractional_error = 136.01628538904833
# dimension = 50, width = 50,  epoch = 209, loss = 0.37468521416497463, fractional_error = 135.27156567641197
# dimension = 50, width = 50,  epoch = 210, loss = 0.20033821884525685, fractional_error = 134.54752745932913
# dimension = 50, width = 50,  epoch = 211, loss = 0.25203410579865254, fractional_error = 133.83712256804858
# dimension = 50, width = 50,  epoch = 212, loss = 0.23657229399685178, fractional_error = 133.14088096537165
# dimension = 50, width = 50,  epoch = 213, loss = 0.3073405667913463, fractional_error = 132.44827519378293
# dimension = 50, width = 50,  epoch = 214, loss = 0.3658988022322553, fractional_error = 131.72815771306134
# dimension = 50, width = 50,  epoch = 215, loss = 0.3315236756245458, fractional_error = 130.99064751790155
# dimension = 50, width = 50,  epoch = 216, loss = 0.43014205798789856, fractional_error = 130.24160029860792
# dimension = 50, width = 50,  epoch = 217, loss = 0.24357040903256197, fractional_error = 129.48451610197745
# dimension = 50, width = 50,  epoch = 218, loss = 0.24562074964849837, fractional_error = 128.7334657852271
# dimension = 50, width = 50,  epoch = 219, loss = 0.2749112273431816, fractional_error = 127.98647680921464
# dimension = 50, width = 50,  epoch = 220, loss = 0.22306358223871536, fractional_error = 127.25514936108033
# dimension = 50, width = 50,  epoch = 221, loss = 0.28688673946727095, fractional_error = 126.53493246656987
# dimension = 50, width = 50,  epoch = 222, loss = 0.1896931503643258, fractional_error = 125.82951481698328
# dimension = 50, width = 50,  epoch = 223, loss = 0.2635656311399304, fractional_error = 125.09486891549516
# dimension = 50, width = 50,  epoch = 224, loss = 0.29730088231944074, fractional_error = 124.3216185680694
# dimension = 50, width = 50,  epoch = 225, loss = 0.20206464335903745, fractional_error = 123.54696152621584
# dimension = 50, width = 50,  epoch = 226, loss = 0.19114544073709427, fractional_error = 122.76478519892237
# dimension = 50, width = 50,  epoch = 227, loss = 0.24688638365933963, fractional_error = 121.98662997545108
# dimension = 50, width = 50,  epoch = 228, loss = 0.20234527165403793, fractional_error = 121.21175389347579
# dimension = 50, width = 50,  epoch = 229, loss = 0.2887269225050582, fractional_error = 120.43737801966418
# dimension = 50, width = 50,  epoch = 230, loss = 0.25526929120542946, fractional_error = 119.66035546014444
# dimension = 50, width = 50,  epoch = 231, loss = 0.28304142583526354, fractional_error = 118.88413750993026
# dimension = 50, width = 50,  epoch = 232, loss = 0.36810161306119904, fractional_error = 118.09608587668443
# dimension = 50, width = 50,  epoch = 233, loss = 0.22136273068776313, fractional_error = 117.27856517680502
# dimension = 50, width = 50,  epoch = 234, loss = 0.24222607628139353, fractional_error = 116.46088295511932
# dimension = 50, width = 50,  epoch = 235, loss = 0.18088308574799858, fractional_error = 115.63489772120917
# dimension = 50, width = 50,  epoch = 236, loss = 0.2395443669371238, fractional_error = 114.75638912082387
# dimension = 50, width = 50,  epoch = 237, loss = 0.1687049877571785, fractional_error = 113.84524009602413
# dimension = 50, width = 50,  epoch = 238, loss = 0.11080654393375713, fractional_error = 112.94073252839283
# dimension = 50, width = 50,  epoch = 239, loss = 0.1766501146058464, fractional_error = 112.01290814772251
# dimension = 50, width = 50,  epoch = 240, loss = 0.27121270752506726, fractional_error = 111.06530705181832
# dimension = 50, width = 50,  epoch = 241, loss = 0.17409260132730467, fractional_error = 110.12325273665888
# dimension = 50, width = 50,  epoch = 242, loss = 0.17851035753708536, fractional_error = 109.149958197024
# dimension = 50, width = 50,  epoch = 243, loss = 0.11247259174232374, fractional_error = 108.15903428510732
# dimension = 50, width = 50,  epoch = 244, loss = 0.16488909008061142, fractional_error = 107.1343634657911
# dimension = 50, width = 50,  epoch = 245, loss = 0.1393272745273439, fractional_error = 106.0974881125622
# dimension = 50, width = 50,  epoch = 246, loss = 0.24754645784120954, fractional_error = 105.01731202173717
# dimension = 50, width = 50,  epoch = 247, loss = 0.17904425840304647, fractional_error = 103.8782056615366
# dimension = 50, width = 50,  epoch = 248, loss = 0.19710930219841188, fractional_error = 102.70769750786106
# dimension = 50, width = 50,  epoch = 249, loss = 0.1739186303110544, fractional_error = 101.48276623353394
# dimension = 50, width = 50,  epoch = 250, loss = 0.20992290327086344, fractional_error = 100.26171183506
# dimension = 50, width = 50,  epoch = 251, loss = 0.15967502393956165, fractional_error = 99.04341014484244
# dimension = 50, width = 50,  epoch = 252, loss = 0.0973542204422282, fractional_error = 97.79861093703147
# dimension = 50, width = 50,  epoch = 253, loss = 0.1788603587660165, fractional_error = 96.52141684041322
# dimension = 50, width = 50,  epoch = 254, loss = 0.1915208870539103, fractional_error = 95.26273053715715
# dimension = 50, width = 50,  epoch = 255, loss = 0.17188052121384761, fractional_error = 93.99638627704343
# dimension = 50, width = 50,  epoch = 256, loss = 0.16189706694989128, fractional_error = 92.7137438305763
# dimension = 50, width = 50,  epoch = 257, loss = 0.16320663926600334, fractional_error = 91.43176984057276
# dimension = 50, width = 50,  epoch = 258, loss = 0.160908404113598, fractional_error = 90.13929783295178
# dimension = 50, width = 50,  epoch = 259, loss = 0.14298885136908954, fractional_error = 88.8205490370811
# dimension = 50, width = 50,  epoch = 260, loss = 0.10649592728490667, fractional_error = 87.54276443525939
# dimension = 50, width = 50,  epoch = 261, loss = 0.08123406641974229, fractional_error = 86.25175562093001
# dimension = 50, width = 50,  epoch = 262, loss = 0.10503637859613868, fractional_error = 84.97895763001326
# dimension = 50, width = 50,  epoch = 263, loss = 0.12686530569696247, fractional_error = 83.7108740584541
# dimension = 50, width = 50,  epoch = 264, loss = 0.06619727334965825, fractional_error = 82.48652256354474
# dimension = 50, width = 50,  epoch = 265, loss = 0.06894735594803032, fractional_error = 81.27600392400133
# dimension = 50, width = 50,  epoch = 266, loss = 0.07723749114287548, fractional_error = 80.0324831626758
# dimension = 50, width = 50,  epoch = 267, loss = 0.09340324258647592, fractional_error = 78.80785830640416
# dimension = 50, width = 50,  epoch = 268, loss = 0.08717270963140163, fractional_error = 77.60725186474781
# dimension = 50, width = 50,  epoch = 269, loss = 0.07854775719122274, fractional_error = 76.43201608147542
# dimension = 50, width = 50,  epoch = 270, loss = 0.07423840227315871, fractional_error = 75.27559034884689
# dimension = 50, width = 50,  epoch = 271, loss = 0.09938673236458204, fractional_error = 74.1283304051629
# dimension = 50, width = 50,  epoch = 272, loss = 0.07392763935111941, fractional_error = 73.0101035901323
# dimension = 50, width = 50,  epoch = 273, loss = 0.08291915100267075, fractional_error = 71.92237898556569
# dimension = 50, width = 50,  epoch = 274, loss = 0.06617578458326306, fractional_error = 70.86430161565978
# dimension = 50, width = 50,  epoch = 275, loss = 0.08004200492289018, fractional_error = 69.83647738440881
# dimension = 50, width = 50,  epoch = 276, loss = 0.09818823405260865, fractional_error = 68.82053249863883
# dimension = 50, width = 50,  epoch = 277, loss = 0.10227360610035552, fractional_error = 67.81030098049727
# dimension = 50, width = 50,  epoch = 278, loss = 0.04175148080180021, fractional_error = 66.85331222676979
# dimension = 50, width = 50,  epoch = 279, loss = 0.05437821123652649, fractional_error = 65.9281524180024
# dimension = 50, width = 50,  epoch = 280, loss = 0.04148330134452255, fractional_error = 65.05178218565034
# dimension = 50, width = 50,  epoch = 281, loss = 0.07162192934220958, fractional_error = 64.18315338481027
# dimension = 50, width = 50,  epoch = 282, loss = 0.02785882135211541, fractional_error = 63.35973041693616
# dimension = 50, width = 50,  epoch = 283, loss = 0.04104642579853728, fractional_error = 62.55438049079272
# dimension = 50, width = 50,  epoch = 284, loss = 0.04507428709877262, fractional_error = 61.772910984800895
# dimension = 50, width = 50,  epoch = 285, loss = 0.08212398059950195, fractional_error = 60.997990332690705
# dimension = 50, width = 50,  epoch = 286, loss = 0.05921025436234449, fractional_error = 60.24106669180267
# dimension = 50, width = 50,  epoch = 287, loss = 0.05877666298010585, fractional_error = 59.49145851164382
# dimension = 50, width = 50,  epoch = 288, loss = 0.025962635048432426, fractional_error = 58.77617350680116
# dimension = 50, width = 50,  epoch = 289, loss = 0.0740814523246217, fractional_error = 58.06890330489276
# dimension = 50, width = 50,  epoch = 290, loss = 0.03419510210405469, fractional_error = 57.39453376646986
# dimension = 50, width = 50,  epoch = 291, loss = 0.04604080811178953, fractional_error = 56.73026024247222
# dimension = 50, width = 50,  epoch = 292, loss = 0.02348695442596391, fractional_error = 56.09124548488901
# dimension = 50, width = 50,  epoch = 293, loss = 0.04560889014746089, fractional_error = 55.466161603938566
# dimension = 50, width = 50,  epoch = 294, loss = 0.03255864430201829, fractional_error = 54.85739958039492
# dimension = 50, width = 50,  epoch = 295, loss = 0.015995327694599774, fractional_error = 54.283235328146176
# dimension = 50, width = 50,  epoch = 296, loss = 0.009562140974695085, fractional_error = 53.74683328865861
# dimension = 50, width = 50,  epoch = 297, loss = 0.09939714149059724, fractional_error = 53.179031772087384
# dimension = 50, width = 50,  epoch = 298, loss = 0.03943142935269024, fractional_error = 52.61824016409202
# dimension = 50, width = 50,  epoch = 299, loss = 0.08565498615293723, fractional_error = 52.01626298433803
# dimension = 50, width = 50,  epoch = 300, loss = 0.014229100516578035, fractional_error = 51.44463407488365
# dimension = 50, width = 50,  epoch = 301, loss = 0.009018872491778015, fractional_error = 50.91026328948364
# dimension = 50, width = 50,  epoch = 302, loss = 0.010046242032751125, fractional_error = 50.40555807553388
# dimension = 50, width = 50,  epoch = 303, loss = 0.04703783687899733, fractional_error = 49.90879256199367
# dimension = 50, width = 50,  epoch = 304, loss = 0.019973711595246527, fractional_error = 49.430079128823785
# dimension = 50, width = 50,  epoch = 305, loss = 0.0026845488893075136, fractional_error = 48.99295209280865
# dimension = 50, width = 50,  epoch = 306, loss = 0.043191861231668426, fractional_error = 48.562657513740376
# dimension = 50, width = 50,  epoch = 307, loss = 0.04146794329718783, fractional_error = 48.13034082640202
# dimension = 50, width = 50,  epoch = 308, loss = 0.014296681813974648, fractional_error = 47.71770947373364
# dimension = 50, width = 50,  epoch = 309, loss = 0.020655704337548028, fractional_error = 47.32806578368337
# dimension = 50, width = 50,  epoch = 310, loss = 0.020841838984232926, fractional_error = 46.95701526096201
# dimension = 50, width = 50,  epoch = 311, loss = 0.03482236754804144, fractional_error = 46.58009746760823
# dimension = 50, width = 50,  epoch = 312, loss = 0.04710446653570314, fractional_error = 46.20948011271734
# dimension = 50, width = 50,  epoch = 313, loss = 0.01256405943217293, fractional_error = 45.854920918797795
# dimension = 50, width = 50,  epoch = 314, loss = 0.013416759858772245, fractional_error = 45.511017481343835
# dimension = 50, width = 50,  epoch = 315, loss = 0.02339440704295251, fractional_error = 45.169899580772224
# dimension = 50, width = 50,  epoch = 316, loss = 0.03340839426686115, fractional_error = 44.83251462478863
# dimension = 50, width = 50,  epoch = 317, loss = 0.007759440814405342, fractional_error = 44.515635206228055
# dimension = 50, width = 50,  epoch = 318, loss = 0.020221354075043375, fractional_error = 44.20005295785345
# dimension = 50, width = 50,  epoch = 319, loss = 0.008002264241877385, fractional_error = 43.90151933805554
# dimension = 50, width = 50,  epoch = 320, loss = 0.03029901810379769, fractional_error = 43.59914394937159
# dimension = 50, width = 50,  epoch = 321, loss = 0.001885690119309879, fractional_error = 43.319874050318035
# dimension = 50, width = 50,  epoch = 322, loss = 0.039035336093225244, fractional_error = 43.01942035255905
# dimension = 50, width = 50,  epoch = 323, loss = 0.004162744193615363, fractional_error = 42.740496003673975
# dimension = 50, width = 50,  epoch = 324, loss = 0.028776202798789105, fractional_error = 42.45237570307195
# dimension = 50, width = 50,  epoch = 325, loss = 0.011804987315307672, fractional_error = 42.17356923947531
# dimension = 50, width = 50,  epoch = 326, loss = 0.027191890182623857, fractional_error = 41.88265252779344
# dimension = 50, width = 50,  epoch = 327, loss = 0.00910043869064952, fractional_error = 41.60471251187519
# dimension = 50, width = 50,  epoch = 328, loss = 0.018392338074433384, fractional_error = 41.32426709476259
# dimension = 50, width = 50,  epoch = 329, loss = 0.018241062898616503, fractional_error = 41.048693652204136
# dimension = 50, width = 50,  epoch = 330, loss = 0.022133624983025218, fractional_error = 40.772531863772045
# dimension = 50, width = 50,  epoch = 331, loss = 0.04142010287714983, fractional_error = 40.494769415847564
# dimension = 50, width = 50,  epoch = 332, loss = 0.04837505717638816, fractional_error = 40.203840806427124
# dimension = 50, width = 50,  epoch = 333, loss = 0.021981326466560657, fractional_error = 39.92360461119501
# dimension = 50, width = 50,  epoch = 334, loss = 0.05134152511558501, fractional_error = 39.62423751243323
# dimension = 50, width = 50,  epoch = 335, loss = 0.03203547840647135, fractional_error = 39.323202437879765
# dimension = 50, width = 50,  epoch = 336, loss = 0.006037389464053955, fractional_error = 39.04261184284528
# dimension = 50, width = 50,  epoch = 337, loss = 0.01090000399529572, fractional_error = 38.77234139809322
# dimension = 50, width = 50,  epoch = 338, loss = 0.022698194246791127, fractional_error = 38.50415561659669
# dimension = 50, width = 50,  epoch = 339, loss = 0.010633151946313457, fractional_error = 38.24797055060104
# dimension = 50, width = 50,  epoch = 340, loss = 0.017572552745369525, fractional_error = 37.99075728500774
# dimension = 50, width = 50,  epoch = 341, loss = 0.027887511819380473, fractional_error = 37.72751908795718
# dimension = 50, width = 50,  epoch = 342, loss = 0.016184808784746575, fractional_error = 37.46973168021158
# dimension = 50, width = 50,  epoch = 343, loss = 0.016612712374935907, fractional_error = 37.218212872726944
# dimension = 50, width = 50,  epoch = 344, loss = 0.010139333122196099, fractional_error = 36.98050887407624
# dimension = 50, width = 50,  epoch = 345, loss = 0.007999659838375086, fractional_error = 36.75424573530779
# dimension = 50, width = 50,  epoch = 346, loss = 0.023628293676644808, fractional_error = 36.53276553526332
# dimension = 50, width = 50,  epoch = 347, loss = 0.011032727959868928, fractional_error = 36.31559474910646
# dimension = 50, width = 50,  epoch = 348, loss = 0.006629519546905736, fractional_error = 36.1107468119229
# dimension = 50, width = 50,  epoch = 349, loss = 0.020539247567132397, fractional_error = 35.9021216254475
# dimension = 50, width = 50,  epoch = 350, loss = 0.00905684755263398, fractional_error = 35.704978176811515
# dimension = 50, width = 50,  epoch = 351, loss = 0.01037667932576835, fractional_error = 35.511159611138446
# dimension = 50, width = 50,  epoch = 352, loss = 0.030664598648536465, fractional_error = 35.30501335848759
# dimension = 50, width = 50,  epoch = 353, loss = 0.018183684648020566, fractional_error = 35.10143513052187
# dimension = 50, width = 50,  epoch = 354, loss = 0.008339155913320021, fractional_error = 34.90334387522731
# dimension = 50, width = 50,  epoch = 355, loss = 0.004318937130115342, fractional_error = 34.715535369492954
# dimension = 50, width = 50,  epoch = 356, loss = 0.011504191995228886, fractional_error = 34.530414700589354
# dimension = 50, width = 50,  epoch = 357, loss = 0.0042501681450404, fractional_error = 34.35422467625462
# dimension = 50, width = 50,  epoch = 358, loss = 0.0016463562364724378, fractional_error = 34.190030470989676
# dimension = 50, width = 50,  epoch = 359, loss = 0.009433460827818476, fractional_error = 34.030743830380416
# dimension = 50, width = 50,  epoch = 360, loss = 0.005803001192078725, fractional_error = 33.87794699887208
# dimension = 50, width = 50,  epoch = 361, loss = 0.013587380348028155, fractional_error = 33.7175532249793
# dimension = 50, width = 50,  epoch = 362, loss = 0.022268108900712208, fractional_error = 33.550530730051584
# dimension = 50, width = 50,  epoch = 363, loss = 0.0037939516666821546, fractional_error = 33.389967933527
# dimension = 50, width = 50,  epoch = 364, loss = 0.013126875830893385, fractional_error = 33.22325328493311
# dimension = 50, width = 50,  epoch = 365, loss = 0.0064134577485155655, fractional_error = 33.0662026515009
# dimension = 50, width = 50,  epoch = 366, loss = 0.01302514799616003, fractional_error = 32.907525899980406
# dimension = 50, width = 50,  epoch = 367, loss = 0.006429058185691583, fractional_error = 32.752483924183636
# dimension = 50, width = 50,  epoch = 368, loss = 0.003199362031014727, fractional_error = 32.6051756358272
# dimension = 50, width = 50,  epoch = 369, loss = 0.018841050290956604, fractional_error = 32.44817228449304
# dimension = 50, width = 50,  epoch = 370, loss = 0.017554188422825218, fractional_error = 32.2862364579877
# dimension = 50, width = 50,  epoch = 371, loss = 0.003634463432273368, fractional_error = 32.13264899896125
# dimension = 50, width = 50,  epoch = 372, loss = 0.014934083689071977, fractional_error = 31.97411734749652
# dimension = 50, width = 50,  epoch = 373, loss = 0.04627260006208686, fractional_error = 31.791356261498905
# dimension = 50, width = 50,  epoch = 374, loss = 0.0056630596019424054, fractional_error = 31.616231227785587
# dimension = 50, width = 50,  epoch = 375, loss = 0.014905079015269886, fractional_error = 31.4435832957646
# dimension = 50, width = 50,  epoch = 376, loss = 0.006319519271520755, fractional_error = 31.27808449462512
# dimension = 50, width = 50,  epoch = 377, loss = 0.0037199765902714284, fractional_error = 31.123350205199856
# dimension = 50, width = 50,  epoch = 378, loss = 0.003061039816255309, fractional_error = 30.976179645462253
# dimension = 50, width = 50,  epoch = 379, loss = 0.010450613640742628, fractional_error = 30.829571521455865
# dimension = 50, width = 50,  epoch = 380, loss = 0.024469760700899457, fractional_error = 30.67185377856153
# dimension = 50, width = 50,  epoch = 381, loss = 0.006322760154238797, fractional_error = 30.518542766966256
# dimension = 50, width = 50,  epoch = 382, loss = 0.002274618567963734, fractional_error = 30.3739215134173
# dimension = 50, width = 50,  epoch = 383, loss = 0.0030710125793941517, fractional_error = 30.236742076444603
# dimension = 50, width = 50,  epoch = 384, loss = 0.00915425331769262, fractional_error = 30.10024331653678
# dimension = 50, width = 50,  epoch = 385, loss = 0.008736627974273919, fractional_error = 29.96476213870654
# dimension = 50, width = 50,  epoch = 386, loss = 0.0042816281482240225, fractional_error = 29.834977118992853
# dimension = 50, width = 50,  epoch = 387, loss = 0.023182426057673913, fractional_error = 29.69401292675336
# dimension = 50, width = 50,  epoch = 388, loss = 0.0044189850523914, fractional_error = 29.558576046249307
# dimension = 50, width = 50,  epoch = 389, loss = 0.005369976703086326, fractional_error = 29.42994015023384
# dimension = 50, width = 50,  epoch = 390, loss = 0.01097539648097919, fractional_error = 29.29736212278586
# dimension = 50, width = 50,  epoch = 391, loss = 0.013972145687862795, fractional_error = 29.16275065538541
# dimension = 50, width = 50,  epoch = 392, loss = 0.010290758681413256, fractional_error = 29.02819182586305
# dimension = 50, width = 50,  epoch = 393, loss = 0.005217884938884716, fractional_error = 28.89575466064727
# dimension = 50, width = 50,  epoch = 394, loss = 0.007223187583209786, fractional_error = 28.767966268990712
# dimension = 50, width = 50,  epoch = 395, loss = 0.00016795905722167268, fractional_error = 28.65266590666269
# dimension = 50, width = 50,  epoch = 396, loss = 0.00022864361220776845, fractional_error = 28.547609216833354
# dimension = 50, width = 50,  epoch = 397, loss = 0.015834544504168345, fractional_error = 28.434919371463778
# dimension = 50, width = 50,  epoch = 398, loss = 0.014470885534988829, fractional_error = 28.309278762411825
# dimension = 50, width = 50,  epoch = 399, loss = 0.00297654026741401, fractional_error = 28.189508754674776
# dimension = 50, width = 50,  epoch = 400, loss = 0.008846230270701111, fractional_error = 28.07159828664147
# dimension = 50, width = 50,  epoch = 401, loss = 0.00016804910881157363, fractional_error = 27.963703940685157
# dimension = 50, width = 50,  epoch = 402, loss = 0.003721095784532038, fractional_error = 27.855316728251015
# dimension = 50, width = 50,  epoch = 403, loss = 0.008493776776254982, fractional_error = 27.744250667458317
# dimension = 50, width = 50,  epoch = 404, loss = 0.0011374719308214526, fractional_error = 27.640069405022928
# dimension = 50, width = 50,  epoch = 405, loss = 0.017110900517204975, fractional_error = 27.52670915030904
# dimension = 50, width = 50,  epoch = 406, loss = 0.0005297366922090186, fractional_error = 27.421439308494712
# dimension = 50, width = 50,  epoch = 407, loss = 5.552905442739601e-05, fractional_error = 27.326479712928528
# dimension = 50, width = 50,  epoch = 408, loss = 0.009823868159907451, fractional_error = 27.225181814852355
# dimension = 50, width = 50,  epoch = 409, loss = 0.002431989807335331, fractional_error = 27.128403617314138
# dimension = 50, width = 50,  epoch = 410, loss = 0.0038029494928881807, fractional_error = 27.03180969329275
# dimension = 50, width = 50,  epoch = 411, loss = 0.004593266592141236, fractional_error = 26.932581114046492
# dimension = 50, width = 50,  epoch = 412, loss = 0.00713247272043529, fractional_error = 26.8326168947662
# dimension = 50, width = 50,  epoch = 413, loss = 0.009687333637929776, fractional_error = 26.722941344989103
# dimension = 50, width = 50,  epoch = 414, loss = 0.004997429875754654, fractional_error = 26.613281754405115
# dimension = 50, width = 50,  epoch = 415, loss = 0.0003104173759429589, fractional_error = 26.5129748515906
# dimension = 50, width = 50,  epoch = 416, loss = 0.005106222551612144, fractional_error = 26.409253062961508
# dimension = 50, width = 50,  epoch = 417, loss = 0.009828539746740163, fractional_error = 26.29931671420707
# dimension = 50, width = 50,  epoch = 418, loss = 0.003949132867798874, fractional_error = 26.194289977784415
# dimension = 50, width = 50,  epoch = 419, loss = 0.04713187232696866, fractional_error = 26.075004021423794
# dimension = 50, width = 50,  epoch = 420, loss = 0.0017600598720016185, fractional_error = 25.96345651250992
# dimension = 50, width = 50,  epoch = 421, loss = 0.008938103466224322, fractional_error = 25.851387435933166
# dimension = 50, width = 50,  epoch = 422, loss = 0.0007951592099704819, fractional_error = 25.746324154738417
# dimension = 50, width = 50,  epoch = 423, loss = 0.0036070529066764352, fractional_error = 25.64207053485338
# dimension = 50, width = 50,  epoch = 424, loss = 0.0023934499295145467, fractional_error = 25.541620803597052
# dimension = 50, width = 50,  epoch = 425, loss = 0.0040412702032152975, fractional_error = 25.440023330800418
# dimension = 50, width = 50,  epoch = 426, loss = 0.0015831307757078008, fractional_error = 25.341659649507616
# dimension = 50, width = 50,  epoch = 427, loss = 7.676206494119903e-05, fractional_error = 25.25294113514468
# dimension = 50, width = 50,  epoch = 428, loss = 0.00831870262774326, fractional_error = 25.152559596695895
# dimension = 50, width = 50,  epoch = 429, loss = 0.003907058694891831, fractional_error = 25.054006606704288
# dimension = 50, width = 50,  epoch = 430, loss = 0.010347723578795336, fractional_error = 24.95304299315701
# dimension = 50, width = 50,  epoch = 431, loss = 0.005807699685638213, fractional_error = 24.85247445227863
# dimension = 50, width = 50,  epoch = 432, loss = 0.001700667553069081, fractional_error = 24.7567853216485
# dimension = 50, width = 50,  epoch = 433, loss = 0.0077239345084222566, fractional_error = 24.65637072069811
# dimension = 50, width = 50,  epoch = 434, loss = 0.0045221700323230946, fractional_error = 24.556373159894157
# dimension = 50, width = 50,  epoch = 435, loss = 0.014486762879662137, fractional_error = 24.441370362788103
# dimension = 50, width = 50,  epoch = 436, loss = 0.007982407701172558, fractional_error = 24.323824482573375
# dimension = 50, width = 50,  epoch = 437, loss = 0.01518204478761039, fractional_error = 24.19301347418439
# dimension = 50, width = 50,  epoch = 438, loss = 0.008201782916292765, fractional_error = 24.059342963568003
# dimension = 50, width = 50,  epoch = 439, loss = 0.001232913378310433, fractional_error = 23.934030723489514
# dimension = 50, width = 50,  epoch = 440, loss = 0.0028715363095446916, fractional_error = 23.814555775941674
# dimension = 50, width = 50,  epoch = 441, loss = 0.000785570617004452, fractional_error = 23.70331703139984
# dimension = 50, width = 50,  epoch = 442, loss = 0.029046057294464786, fractional_error = 23.562210938935348
# dimension = 50, width = 50,  epoch = 443, loss = 0.005543549844485397, fractional_error = 23.428447415743054
# ...
# dimension = 50, width = 50,  epoch = 1005, loss = 1.986334214504322e-07, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1006, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1007, loss = 6.219091028280483e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1008, loss = 0.00045350030852965106, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1009, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1010, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1011, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1012, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1013, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1014, loss = 0.000184973842872059, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1015, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1016, loss = 0.00040472085020150557, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1017, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1018, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1019, loss = 0.005733510395489391, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1020, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1021, loss = 0.0018794560397355704, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1022, loss = 0.0004192644985543963, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1023, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1024, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1025, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1026, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1027, loss = 0.0008918198185049203, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1028, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1029, loss = 3.0110965430080418e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1030, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1031, loss = 0.004841485188610909, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1032, loss = 5.269644455564457e-07, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1033, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1034, loss = 8.94224209207922e-08, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1035, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1036, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1037, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1038, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1039, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1040, loss = 0.0007863759105450431, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1041, loss = 0.0023562572631440895, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1042, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1043, loss = 0.009164564914196812, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1044, loss = 0.0001520931607109832, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1045, loss = 1.3715550478583139e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1046, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1047, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1048, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1049, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1050, loss = 0.009490355295567451, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1051, loss = 2.0191277801503e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1052, loss = 1.7434550708877094e-07, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1053, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1054, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1055, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1056, loss = 5.261186433817458e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1057, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1058, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1059, loss = 0.00039027190853682317, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1060, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1061, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1062, loss = 1.7074141939924488e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1063, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1064, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1065, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1066, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1067, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1068, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1069, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1070, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1071, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1072, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1073, loss = 0.0003524863274611421, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1074, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1075, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1076, loss = 1.0417294466756847e-06, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1077, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1078, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1079, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1080, loss = 1.1957488789431846e-06, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1081, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1082, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1083, loss = 0.0021960376491641596, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1084, loss = 0.007201651904135917, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1085, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1086, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1087, loss = 1.4575729286016575e-08, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1088, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1089, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1090, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1091, loss = 2.2493025134766447e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1092, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1093, loss = 0.002115599891658396, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1094, loss = 5.138987619108687e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1095, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1096, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1097, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1098, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1099, loss = 5.8115443816973144e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1100, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1101, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1102, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1103, loss = 0.0012682094367457897, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1104, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1105, loss = 6.945354363321099e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1106, loss = 0.002074685282140598, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1107, loss = 0.00039599061383037334, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1108, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1109, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1110, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1111, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1112, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1113, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1114, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1115, loss = 7.403537897497668e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1116, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1117, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1118, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1119, loss = 0.019045026943754397, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1120, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1121, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1122, loss = 0.00014194256727709446, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1123, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1124, loss = 0.0018758875426310225, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1125, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1126, loss = 1.6137801228781857e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1127, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1128, loss = 0.0003892208463693906, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1129, loss = 0.00017013512684828412, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1130, loss = 0.015553664927679619, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1131, loss = 6.011488088815404e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1132, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1133, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1134, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1135, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1136, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1137, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1138, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1139, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1140, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1141, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1142, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1143, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1144, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1145, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1146, loss = 0.00040832002598611, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1147, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1148, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1149, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1150, loss = 0.0028065830969023335, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1151, loss = 0.0001062944417376876, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1152, loss = 4.4830329034316675e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1153, loss = 4.649727598659787e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1154, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1155, loss = 0.0017933250172071722, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1156, loss = 3.888849781571885e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1157, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1158, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1159, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1160, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1161, loss = 0.0005889537945486494, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1162, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1163, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1164, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1165, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1166, loss = 6.730199424844383e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1167, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1168, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1169, loss = 0.00026403094939185805, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1170, loss = 0.0019699804782045537, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1171, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1172, loss = 4.2746265600797974e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1173, loss = 8.573468584485209e-05, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1174, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1175, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1176, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1177, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1178, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1179, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1180, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1181, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1182, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1183, loss = 0.0, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1184, loss = 0.004852202161213546, fractional_error = 0.0001
# dimension = 50, width = 50,  epoch = 1185, loss = 0.0, fractional_error = 0.0001

# %% [markdown]
# ## 6. Plot the Output

# %%
# loss_first_100_epochs = loss_epoch[0:100]
# error_first_100_epochs = error_epoch[0:100]

# %%
# x_values = range(0, 100)

# %%
# plt.plot(x_values, loss_first_100_epochs)
# plt.xlabel('Epoch')
# plt.ylabel('Empirical loss')
# plt.yscale('log')
# plt.title('Change in empirical loss in first 100 epochs')
# plt.show()
# plt.plot(x_values, error_first_100_epochs)
# plt.xlabel('Epoch')
# plt.ylabel('Fractional error')
# plt.yscale('log')
# plt.title('Change in fractional error in first 100 epochs')
# plt.show()

# %%
x_axis = dimension_list
y_axis = net_width_list
fig, axee = plt.subplots(figsize=(8, 6))
axee = sns.heatmap(energy_loss_mat_e, xticklabels=x_axis,yticklabels=y_axis, ax=axee, cmap='coolwarm', norm=LogNorm())
axee.invert_yaxis()
axee.set_xlabel("PDE dimension")
axee.set_ylabel("Net Width")
axee.set_title("Empirical Loss (Energy)")
cbar = axee.collections[0].colorbar
cbar.set_label('Empirical Loss (log-scale)')
plt.show()

fig, axef = plt.subplots(figsize=(8, 6))
axef = sns.heatmap(energy_fractional_error, xticklabels=dimension_list, yticklabels=net_width_list, ax=axef, cmap='coolwarm', norm=LogNorm())
plt.gca().invert_yaxis()
axef.set_xlabel("PDE dimension")
axef.set_ylabel("Net Width")
axef.set_title("Fractional Error (Energy)")
cbar = axef.collections[0].colorbar
cbar.set_label('Fractional Error (log-scale)')
plt.show()

label = f'dimension:{input_width},\n net width:{net_width_list},\n training data:{batch_size}'
plt.plot(range(epoch), loss_epoch, label = label)
plt.title('Empirical Loss vs Epoch (Energy)')
plt.xlabel('Epoch')
plt.ylabel('Empirical Loss')
plt.yscale('log')
plt.legend()
plt.show()

plt.plot(range(epoch), error_epoch, label = label)
plt.title('Fractional Error vs Epoch (Energy)')
plt.xlabel('Epoch')
plt.ylabel('Fractional Error')
plt.yscale('log')
plt.legend()
plt.show()
