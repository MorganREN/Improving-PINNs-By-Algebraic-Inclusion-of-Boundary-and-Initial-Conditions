# %% [markdown]
# **Inviscid Burgers’ Equation**
#
# For a given field $u(x, t)$ and diffusion coefficient (or kinematic viscosity, as in the original fluid mechanical context)  $\nu$ , the general form of Burgers' equation (also known as viscous Burgers' equation) in one space dimension is the dissipative system:
#
# Burger's equation is the following:
#
# $$\frac{\partial u(x, t)}{\partial t}+u \frac{\partial u(x, t)}{\partial x}=\nu \frac{\partial^{2} u(x, t)}{\partial x^{2}}$$
# A special solution to the above PDE is:
#
# $$u(x, t)=1-\tanh \frac{x-x_{c}-t}{2 \nu}$$
#
# here i define $x_c$ = 0:
# $$u(x, t)=1-\tanh \frac{x-t}{2 \nu}$$

# %% [markdown]
# \begin{array}{c}
# \frac{\partial u}{\partial t}+u \frac{\partial u}{\partial x}=\nu \frac{\partial^{2} u(x, t)}{\partial x^{2}}, (x,t)∈[0,1] × [0,1]  \\
# u(x, 0)=F(x)=1-\tanh \frac{x}{2 \nu}, x∈[0,1]\\
# u(x,t) = g(x,t) = 1-\tanh \frac{x-t}{2 \nu}, x ∈ \{0, 1\}
# \end{array}

# %% [markdown]
# ## 1.Setup

# %%
import torch
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import matplotlib.pyplot as plt
from math import *
import time
import copy


# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# check pytorch version
print(torch.__version__)
# Out:
# 1.13.1+cu117

# %% [markdown]
# ## 2.Hyperparameter

# %%
dimension = 2
input_width,layer_width = dimension, 4
layer_depth = 5
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## 3.Neural Architecture

# %%
# %%
# activation function
def activation(x):
    return torch.mul(x, torch.sigmoid(x))


class Net(torch.nn.Module):
    def __init__(self,input_width,layer_width,layer_depth):
        super(Net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        for i in range(layer_depth-1):
            setattr(self, 'layer'+str(i), torch.nn.Linear(layer_width, layer_width))
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x,layer_depth):
        y = activation(self.layer_in(x))
        for i in range(layer_depth-1):
            y = activation(getattr(self, 'layer'+str(i))(y))
        output = self.layer_out(y)
        return output

# %% [markdown]
# ${\rm N}(\vec{x}) := {\rm A}_{\rm 4}(\sigma{\rm A}_3({\sigma}{\rm A}_2({\sigma}{\rm A}_{\rm 1}(\vec{x}))))\ ,$, where
#
#
# ${\rm A}_{\rm 1}: \mathbb{R}^2{→}\mathbb{R}^w$, ${\rm A}_2: \mathbb{R}^w{→}\mathbb{R}^w$, ${\rm A}_3: \mathbb{R}^w{→}\mathbb{R}^w$, ${\rm A}_{\rm 4}: \mathbb{R}^w{→}\mathbb{R}$,
#
# note: there are $2w^2+6w+1$ parameters need to be trained in total in ${\rm N}(x)$

# %% [markdown]
# ## 4.Training setup

# %% [markdown]
# ### 4.1 Initialize the weights using Xavier normal initialization

# %%
# %%
# Xavier normal initialization for weights:
#             mean = 0 std = gain * sqrt(2 / fan_in + fan_out)
# zero initialization for biases
def initialize_weights(self):
    for m in self.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight.data)
            if m.bias is not None:
                m.bias.data.zero_()

# %% [markdown]
# ### 4.2 Define $u_0(x)$
#
# $$ [0,1] {\ni} x {↦} u_0(x) =1- \tanh \frac{x}{2 \nu}{∈} {\mathbb R} $$

# %%
# Define u_0
def u_0x(X):
    x = X[:,0]
    temp1 = torch.sub(1,torch.tanh(x/(2*nu)))
    u_temp = temp1
    return u_temp.reshape([X.size()[0], 1]).to(device)

# %% [markdown]
# ### 4.3 Define the exact solution
#
# $$[0,1]{×}[0,1]{\ni}(x, t) {↦} u(x, t)=1-\tanh \frac{x-t}{2 \nu} {∈} {\mathbb R}$$

# %%
# defination of exact solution
def u_ex(X):     
    x = X[:,0]
    t = X[:,1]
    
    temp1 = torch.sub(1,torch.tanh((x-t)/(2*nu)))
    u_temp = temp1
    return u_temp.reshape([x.size()[0], 1]).to(device)

# %% [markdown]
# ### 4.4 Define g(x,t)
#
# $$ \{0,1\}×[0,1] \ni (x,t) ↦ g(x,t) = 1-\tanh \frac{x-t}{2 \nu} ∈ {\mathbb R}$$

# %%
def g_x(X):     
    x = X[:,0].to(device)
    t = X[:,1].to(device)
    temp1 = torch.sub(1,torch.tanh((x-t)/(2*nu)))
    u_temp = temp1
    return u_temp.reshape([x.size()[0], 1]).to(device)

# %%
def g_0x(X):
    x = torch.zeros([X.shape[0],1])[:,0].to(device)
    x.requires_grad = True
    t = X[:,1].to(device)
    temp1 = torch.sub(1,torch.tanh((x-t)/(2*nu)))
    u_temp = temp1
    return u_temp.reshape([x.size()[0], 1]).to(device)

# %%
def g_1x(X):
    x = torch.ones([X.shape[0],1])[:,0].to(device)
    x.requires_grad = True
    t = X[:,1].to(device)
    temp1 = torch.sub(1,torch.tanh((x-t)/(2*nu)))
    u_temp = temp1
    return u_temp.reshape([x.size()[0], 1]).to(device)

# %% [markdown]
# ### 4.4 Build the model
#
# $x = {\vec X}[:,0]$
#
# $t = {\vec X}[:,1]$
#
# Model for training on initial and boundary:$${\rm model}({x,t}) := {\rm N}(x, t)  $$
# Model for training on boundary:$${\rm model}({x,t}) := {\rm N}(x, t) ⋅ x ⋅ (1-x)  +  (1-x) ⋅ g(0,t) + x{⋅} g(1,t)$$
# Model for training on initial:$${\rm model}({x,t}) := {\rm N}(x, t)  ⋅ t  +  u_0(x) \cdot (1-t)$$

# %%
def model(X,initial = False, boundary = False):
    x = X[:,0]
    t = X[:,1].reshape([x.size()[0], 1])
    x_temp = x.reshape([x.size()[0], 1])
    t_temp = t.reshape([t.size()[0], 1])
    x_minus = (1.0-x).reshape([x.size()[0], 1])
    t_minus = (1.0-t).reshape([t.size()[0], 1])

    if initial == False and boundary == False:
        term1 = net(X,layer_depth)
        model_u_temp = term1
    elif initial == False and boundary == True:
        # term1 = net(X,layer_depth) * x_temp * x_minus
        term1 = torch.mul(net(X,layer_depth),torch.mul(x_temp,x_minus))
        term2 = torch.mul(g_0x(X),x_minus)
        term3 = torch.mul(g_1x(X),x_temp)
        model_u_temp =  torch.add(torch.add(term1,term2),term3)
    else:
        term1 = torch.mul(net(X,layer_depth),t)
        term2 = torch.mul(u_0x(X),t_minus)
        model_u_temp =  torch.add(term1,term2)
                   
    return model_u_temp.reshape([x.size()[0], 1]).to(device)

# %% [markdown]
# #### 4.5.1 $ν_1$ generator
#
# Generate random points $(x_n, t_n)$ from $[0,1] × [0,1]$

# %%
# generate points by random
def generate_sample_one(data_size):
    sample_temp = torch.rand(data_size, dimension)
    sample_temp.requires_grad = True
    return sample_temp.to(device)

# %% [markdown]
# #### 4.5.2 $ν_2$ generator
#
# Generate random points $x_n$ from $[0,1]$

# %%
def generate_sample_two(data_size):
    sample_temp = torch.rand(data_size, dimension)
    sample_temp[:,1] = 0
    sample_temp.requires_grad = True
    return sample_temp.to(device)

# %% [markdown]
# #### 4.5.3 $ν_3$ generator
#
# Generate random points $x_n$ from ${\{0,1\}}$

# %%
def generate_sample_three(data_size):
    sample_temp = torch.rand(data_size, dimension)
    sample_temp[0: len(sample_temp)//2, 0] = 0
    sample_temp[len(sample_temp)//2: len(sample_temp), 0] = 1
    sample_temp.requires_grad = True
    return sample_temp.to(device)

# %% [markdown]
# ### 4.6 Define Loss function
#
# Loss for training on initial and boundary:$$Loss(û) = ||{\frac{∂û}{∂t}} +  \hat{u} {\frac{∂û}{∂x}} - \nu \frac{\partial^{2} û}{\partial x^{2}}||^2_{[0,1]{×}{[0,1]},{ν_1}} +||û-F(x)||^2_{t=0,[0,1], ν_2} + ||û-g(x,t)||^2_{\{0,1\}{×}{[0,1]}, ν_3}$$
# Loss for training on boundary:$$Loss(û) = ||{\frac{∂û}{∂t}} +  \hat{u} {\frac{∂û}{∂x}} - \nu \frac{\partial^{2} û}{\partial x^{2}}||^2_{[0,1]{×}{[0,1]},{ν_1}} +||û-F(x)||^2_{t=0,[0,1], ν_2} $$
#
# Loss for training on initial:$$Loss(û) = ||{\frac{∂û}{∂t}} +  \hat{u} {\frac{∂û}{∂x}} - \nu \frac{\partial^{2} û}{\partial x^{2}}||^2_{[0,1]{×}{[0,1]},{ν_1}} + ||û-g(x,t)||^2_{\{0,1\}{×}{[0,1]}, ν_3}$$

# %%
# loss function to DGM by auto differential
def loss_function(x1, x2, x3, initial=False, boundary=False):
    # first term
    u_hat = model(x1,initial, boundary)
    grad_u_hat = torch.autograd.grad(outputs = u_hat, inputs = x1, grad_outputs = torch.ones(u_hat.shape).to(device), create_graph = True)  # dx and dt
    dx = grad_u_hat[0][:, 0]  # dx
    dt = grad_u_hat[0][:, 1]  # dt
    # dxx and dtt
    grad_dx = torch.autograd.grad(outputs = dx, inputs = x1, grad_outputs = torch.ones(dx.shape).to(device).to(device), create_graph = True)
    dxx = grad_dx[0][:, 0]
    dtt = grad_dx[0][:, 1]
    # loss1 = torch.sum((dt + torch.multiply(u_hat.T,dx))**2) / len(x1)
    loss1 = torch.add(dt, torch.mul(u_hat.T,dx))
    loss1 = torch.sub(loss1, torch.mul(nu, dxx))
    loss1 = torch.sum(torch.mul(loss1,loss1)) / len(x1)

    # bias = torch.square(torch.mean(dt + torch.multiply(u_hat.T,dx)))
    # variance = torch.mean(torch.square(dt + torch.multiply(u_hat.T,dx) - torch.mean(dt + torch.multiply(u_hat.T,dx))))
    #second term
    if initial == False:
        u_hat2 = model(x2,initial, boundary)
        u0 = u_0x(x2)
        loss2 = torch.sub(u_hat2, u0)
        loss2 = torch.sum(torch.mul(loss2,loss2)) / len(x2)
    else:
        loss2 = 0

    #third term

    if boundary == False:
        u_hat3 = model(x3,initial, boundary)
        u_ex3 = g_x(x3)
        loss3 = torch.sub(u_hat3, u_ex3)
        loss3 = torch.sum(torch.mul(loss3,loss3)) / len(x3)
    else:
        loss3 = 0
    return loss1 + loss2 + loss3
    # return loss

# %% [markdown]
# ## 5.Doing the training

# %%
def plot_loss_epoch(loss_record_all, error_record_all,epoch, var_loss, var_error,nu):
    para = nu
    fig = plt.figure()
    # Set subplots size
    fig.set_figheight(15)
    fig.set_figwidth(20)

    ax = fig.add_subplot(2, 1, 1)
    # plot a smooth curve of loss
    ax.plot(np.arange(epoch), loss_record_all[0])
    ax.plot(np.arange(epoch), loss_record_all[1])
    ax.plot(np.arange(epoch), loss_record_all[2])
    # append error bar to the plot 
    ax.errorbar(np.arange(epoch), loss_record_all[0], yerr=var_loss[0], label='vanilla')
    ax.errorbar(np.arange(epoch), loss_record_all[1], yerr=var_loss[1], label='boundary-included')
    ax.errorbar(np.arange(epoch), loss_record_all[2], yerr=var_loss[2], label='initial-included')

    ax.set_xlabel('epoch')
    ax.set_ylabel('Empirical loss')
    ax.set_title("Empirical loss for 1D Burgers' equation, epoch = 30000, nu: {}, lr = 0.0001, data_size = 3000".format(para), fontsize=12)
    ax.set_yscale("log")
    ax.legend()

    ax = fig.add_subplot(2, 1, 2)
    # plot a smooth curve of loss
    ax.plot(np.arange(epoch), error_record_all[0])
    ax.plot(np.arange(epoch), error_record_all[1])
    ax.plot(np.arange(epoch), error_record_all[2])
    # append error bar to the plot
    ax.errorbar(np.arange(epoch), error_record_all[0], yerr=var_error[0], label='vanilla')
    ax.errorbar(np.arange(epoch), error_record_all[1], yerr=var_error[1], label='boundary-included')
    ax.errorbar(np.arange(epoch), error_record_all[2], yerr=var_error[2], label='initial-included')

    ax.set_xlabel('epoch')
    ax.set_ylabel('Fractional error w.r.t true solution')
    ax.set_title("Fractional error w.r.t true solution, epoch = 30000, nu: {}, lr = 0.0001,data_size = 3000".format(para), fontsize=12)
    ax.set_yscale("log")
    ax.legend()

    plt.savefig('loss_epoch,1D, epoch = 30000, nu: {}, lr = 0.0001,data_size = 3000.png'.format(para))

# %%
dimension = 2
input_width,layer_width = dimension, 4
layer_depth = 2

# Testing data
test_data = torch.zeros((101, 101, 2))
for i in range(101):
  x_test = i / 100
  for j in range(101):
    t_test = j / 100
    test_data[i][j][0] = x_test
    test_data[i][j][1] = t_test
test_data = torch.reshape(test_data, (101*101, 2)).to(device)



def cal_error(x,initial = True, boundary = True):
    u_hat = model(x,initial, boundary)
    u = u_ex(x)
    error = ((u_hat - u).norm(2))**2 / (u.norm(2))**2
    return error

# %%
epoch = 30000
import pickle
# layer_width_list = [4,40,200,300,1000,2000,3000]
nu_list = [0.01,0.1,0.5,1]

for i in range(len(nu_list)):
  nu = nu_list[i]
  print("current nu_list: {}".format(nu))
  loss_record_all = [[],[],[]]
  error_record_all = [[],[],[]]
  for i in range(5):
    print("current run: {}".format(i))
    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    data_size = 3000
    x1 = generate_sample_one(data_size//3)
    x2 = generate_sample_two(data_size//3)
    x3 = generate_sample_three(data_size//3)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = False, boundary=False)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=False, boundary=False)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())
    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    # plot_heatmap("venilla",initial=False, boundary=False)
    loss_record_all[0].append(loss_record)
    error_record_all[0].append(error_record)

    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = False, boundary=True)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=False, boundary=True)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())

    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    loss_record_all[1].append(loss_record)
    error_record_all[1].append(error_record)
    # plot_heatmap("boundary-included",initial=False, boundary=True)


    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = True, boundary=False)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=True, boundary=False)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())
    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    # plot_heatmap("initial-included",initial=True, boundary=False)
    loss_record_all[2].append(loss_record)
    error_record_all[2].append(error_record)

  with open('1D_burger_loss_record_all_nu={}.pkl'.format(nu), 'wb') as f:
      pickle.dump([loss_record_all,error_record_all], f)

  avg_loss_record = []
  avg_error_record = []
  var_error_record = []
  var_loss_record = []
  for i in range(len(loss_record_all)):
      avg_loss_record.append(np.mean(loss_record_all[i], axis=0))
      avg_error_record.append(np.mean(error_record_all[i], axis=0))
      var_error_record.append(np.var(error_record_all[i], axis=0))
      var_loss_record.append(np.var(loss_record_all[i], axis=0))

  plot_loss_epoch(avg_loss_record, avg_error_record, epoch,var_loss_record, var_error_record, nu)
# Out:
# current nu_list: 0.01
# current run: 0
# current epoch is:  00
# current loss is:  tensor(2.1426, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4021, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.3242, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.2434, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.2134, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.1907, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.1784, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.1575, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.1457, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.1357, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.1122, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.1020, device='cuda:0')
# total time is:  577.7439255714417 seconds
# current epoch is:  00
# current loss is:  tensor(26.3444, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(16.8913, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(12.1132, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(10.9351, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(9.5062, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(8.0743, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.3587, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(6.8108, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(6.4263, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(6.1443, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(5.9271, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(5.7613, device='cuda:0')
# total time is:  823.1933603286743 seconds
# current epoch is:  00
# current loss is:  tensor(11.5551, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(4.3351, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(2.0785, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(1.7248, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(1.6394, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(1.5756, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(1.5119, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(1.4549, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(1.3921, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.3589, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.3406, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.3281, device='cuda:0')
# total time is:  679.2882277965546 seconds
# current run: 1
# current epoch is:  00
# current loss is:  tensor(2.2988, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4354, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.3716, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.2986, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.2618, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.2134, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.1783, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.1529, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.1347, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.1237, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.1159, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.1104, device='cuda:0')
# total time is:  572.3409142494202 seconds
# current epoch is:  00
# current loss is:  tensor(17.6449, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(13.2060, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(8.8783, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(8.5307, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(8.4603, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(8.4186, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(8.3420, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(8.2225, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(8.1173, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(8.0463, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(7.9985, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(7.9640, device='cuda:0')
# total time is:  820.6243410110474 seconds
# current epoch is:  00
# current loss is:  tensor(9.4576, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(2.5948, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(2.1397, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(1.1331, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.8492, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.7917, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.7169, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.6745, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.6603, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.6543, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.6506, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.6478, device='cuda:0')
# total time is:  675.1877114772797 seconds
# current run: 2
# current epoch is:  00
# current loss is:  tensor(1.9042, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4429, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.3842, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.3064, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.2696, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.2488, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.2287, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.2055, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.1802, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.1561, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.1334, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.1146, device='cuda:0')
# total time is:  571.9491086006165 seconds
# current epoch is:  00
# current loss is:  tensor(29.7434, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(24.1851, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(14.3885, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(8.9586, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(7.1629, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(6.1619, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(5.4685, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(5.0124, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.7819, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(4.6713, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(4.5890, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(4.5070, device='cuda:0')
# total time is:  831.4130823612213 seconds
# current epoch is:  00
# current loss is:  tensor(10.2101, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(4.4690, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(1.1624, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.8483, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.7155, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.6705, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.6195, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.5542, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.5105, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.4945, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.4902, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.4869, device='cuda:0')
# total time is:  677.1740403175354 seconds
# current run: 3
# current epoch is:  00
# current loss is:  tensor(2.0132, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4305, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.3542, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.2901, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.1446, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0937, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0617, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0393, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0281, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0216, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0196, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0186, device='cuda:0')
# total time is:  571.4891700744629 seconds
# current epoch is:  00
# current loss is:  tensor(23.0578, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(19.5144, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(12.1807, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(6.9088, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(4.5545, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.9913, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(3.8340, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.7520, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(3.7010, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.6621, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.6313, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(3.6036, device='cuda:0')
# total time is:  819.2853698730469 seconds
# current epoch is:  00
# current loss is:  tensor(4.8794, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(2.9869, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(1.7358, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(1.2798, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(1.1051, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.8736, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.7025, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.6293, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.6016, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.5881, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.5810, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.5776, device='cuda:0')
# total time is:  675.6577014923096 seconds
# current run: 4
# current epoch is:  00
# current loss is:  tensor(2.0270, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4638, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.3094, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.1484, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.1139, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.1021, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0936, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0867, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0813, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0769, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0733, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0709, device='cuda:0')
# total time is:  573.0476551055908 seconds
# current epoch is:  00
# current loss is:  tensor(23.8228, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(19.0265, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(14.2515, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(8.6050, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(6.7189, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(6.1669, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(5.8533, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(5.6039, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(5.4111, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(5.2701, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(5.1665, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(5.0861, device='cuda:0')
# total time is:  819.9757304191589 seconds
# current epoch is:  00
# current loss is:  tensor(8.7949, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(3.9678, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(1.5365, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(1.1725, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(1.0810, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.9641, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.7827, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.7088, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.6827, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.6563, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.6298, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.6057, device='cuda:0')
# total time is:  676.0740840435028 seconds
# current nu_list: 0.1
# current run: 0
# current epoch is:  00
# current loss is:  tensor(2.1725, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.1759, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0447, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0174, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0005, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(8.4161e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(7.1311e-05, device='cuda:0')
# total time is:  541.6255371570587 seconds
# current epoch is:  00
# current loss is:  tensor(3.2173, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.3693, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.1278, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0709, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0375, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0288, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0221, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0177, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0163, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0158, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0156, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0153, device='cuda:0')
# total time is:  806.963475227356 seconds
# current epoch is:  00
# current loss is:  tensor(2.1175, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.1338, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0473, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0277, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0087, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0042, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0028, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0024, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0022, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0019, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0015, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0011, device='cuda:0')
# total time is:  645.2517652511597 seconds
# current run: 1
# current epoch is:  00
# current loss is:  tensor(1.9210, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0906, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0004, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(5.7819e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.6577e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.4412e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(3.2767e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.1396e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(2.9702e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.8187e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.6643e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.5829e-05, device='cuda:0')
# total time is:  538.0170342922211 seconds
# current epoch is:  00
# current loss is:  tensor(3.4054, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.5699, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.1930, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0327, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0233, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0138, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0058, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0033, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0029, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0027, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0025, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0024, device='cuda:0')
# total time is:  804.6381618976593 seconds
# current epoch is:  00
# current loss is:  tensor(2.5785, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.1599, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0379, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0108, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0058, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0037, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0033, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0032, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0031, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0031, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0030, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0030, device='cuda:0')
# total time is:  637.2776136398315 seconds
# current run: 2
# current epoch is:  00
# current loss is:  tensor(1.8986, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.1434, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0487, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0044, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0007, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0005, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0002, device='cuda:0')
# total time is:  538.1333343982697 seconds
# current epoch is:  00
# current loss is:  tensor(3.4208, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.2705, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.1162, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0944, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0181, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0085, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0065, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0058, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0053, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0049, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0045, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0023, device='cuda:0')
# total time is:  804.3776612281799 seconds
# current epoch is:  00
# current loss is:  tensor(2.5054, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.6727, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.1216, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0368, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0215, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0157, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0075, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0063, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0055, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0048, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0042, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0038, device='cuda:0')
# total time is:  632.6522953510284 seconds
# current run: 3
# current epoch is:  00
# current loss is:  tensor(1.9908, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0824, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0026, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.3740e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(5.3961e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.2362e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.5331e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.0908e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.7939e-05, device='cuda:0')
# total time is:  532.4120123386383 seconds
# current epoch is:  00
# current loss is:  tensor(3.8633, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4348, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.2450, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0696, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0260, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0191, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0165, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0151, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0142, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0134, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0127, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0119, device='cuda:0')
# total time is:  796.4136464595795 seconds
# current epoch is:  00
# current loss is:  tensor(2.0376, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.2744, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0307, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0215, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0130, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0103, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0086, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0070, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0062, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0057, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0053, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0050, device='cuda:0')
# total time is:  632.0085091590881 seconds
# current run: 4
# current epoch is:  00
# current loss is:  tensor(1.7374, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.1243, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0235, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0006, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.8805e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(5.2055e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.1363e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.5162e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.0809e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.7312e-05, device='cuda:0')
# total time is:  530.501229763031 seconds
# current epoch is:  00
# current loss is:  tensor(3.3789, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.4192, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.1415, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.1235, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.1091, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.1015, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0882, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0328, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0111, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0099, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0094, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0088, device='cuda:0')
# total time is:  795.4955832958221 seconds
# current epoch is:  00
# current loss is:  tensor(2.4037, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.5391, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0961, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0372, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0180, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(0.0096, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(0.0073, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(0.0062, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(0.0052, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(0.0045, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(0.0039, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(0.0034, device='cuda:0')
# total time is:  633.0283310413361 seconds
# current nu_list: 0.5
# current run: 0
# current epoch is:  00
# current loss is:  tensor(1.8076, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0028, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0008, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(5.6991e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.8639e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(1.4943e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(9.4480e-07, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(8.0671e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(7.1710e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(7.5486e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(6.5934e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(6.3863e-07, device='cuda:0')
# total time is:  533.600857257843 seconds
# current epoch is:  00
# current loss is:  tensor(0.0374, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(7.8608e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(2.2481e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(2.4230e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(9.5071e-07, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(2.7623e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(4.7337e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.3734e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.9721e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.0667e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.0408e-07, device='cuda:0')
# total time is:  802.1820540428162 seconds
# current epoch is:  00
# current loss is:  tensor(1.5227, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0061, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0010, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.9337e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(1.8763e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(8.2381e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(5.2330e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.1412e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.4722e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.9575e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.5399e-06, device='cuda:0')
# total time is:  637.5832521915436 seconds
# current run: 1
# current epoch is:  00
# current loss is:  tensor(1.7323, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0056, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0007, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(7.8765e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(4.0623e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(2.3587e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(1.2786e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(7.2574e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(4.7651e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.3573e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.3841e-07, device='cuda:0')
# total time is:  534.8022632598877 seconds
# current epoch is:  00
# current loss is:  tensor(0.0794, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0011, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(1.5879e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(4.9746e-06, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(8.2899e-07, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(6.5809e-07, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(6.0598e-07, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(4.0571e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(3.7036e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.4178e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.1844e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.9871e-07, device='cuda:0')
# total time is:  800.479150056839 seconds
# current epoch is:  00
# current loss is:  tensor(1.4814, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0108, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0004, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(9.5496e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(2.2105e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(1.4941e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(4.0159e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(2.6447e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(2.2155e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.9622e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.7704e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.6154e-06, device='cuda:0')
# total time is:  634.261935710907 seconds
# current run: 2
# current epoch is:  00
# current loss is:  tensor(1.5153, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0007, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(6.6612e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(1.6261e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(7.9993e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(4.1362e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(2.0678e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(1.2987e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(4.0038e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.3226e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(4.4987e-08, device='cuda:0')
# total time is:  535.918692111969 seconds
# current epoch is:  00
# current loss is:  tensor(0.0606, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(9.1899e-05, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(7.6806e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(4.3580e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(2.2216e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(7.5708e-07, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(4.9850e-07, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.8000e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(3.0596e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.6381e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.1947e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.9353e-07, device='cuda:0')
# total time is:  807.0988900661469 seconds
# current epoch is:  00
# current loss is:  tensor(1.4703, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0052, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0023, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(5.0441e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(2.1886e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.6942e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(4.9920e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(3.9928e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.3619e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.8572e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.3942e-06, device='cuda:0')
# total time is:  635.7718183994293 seconds
# current run: 3
# current epoch is:  00
# current loss is:  tensor(1.6205, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0026, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(7.8158e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(4.1992e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(7.1617e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(8.5345e-07, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.1912e-07, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(6.5102e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(6.4122e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.5475e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(5.9934e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(5.9829e-07, device='cuda:0')
# total time is:  533.6135902404785 seconds
# current epoch is:  00
# current loss is:  tensor(0.2778, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0005, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(9.3367e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(6.7830e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(2.6464e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(8.3815e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(6.1133e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(4.2446e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(2.9569e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.2880e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.7153e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.3263e-06, device='cuda:0')
# total time is:  791.9699859619141 seconds
# current epoch is:  00
# current loss is:  tensor(1.5713, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0010, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0005, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(2.7065e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(7.4772e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.9697e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(2.5215e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.7640e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.3739e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.1747e-06, device='cuda:0')
# total time is:  633.6371374130249 seconds
# current run: 4
# current epoch is:  00
# current loss is:  tensor(1.5419, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0011, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0005, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(2.5103e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(2.4679e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(1.1226e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(8.2267e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(6.6069e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(5.3970e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.8433e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(3.8462e-07, device='cuda:0')
# total time is:  535.0108726024628 seconds
# current epoch is:  00
# current loss is:  tensor(0.2854, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(9.7171e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(7.5430e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.2360e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(4.3135e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(3.5886e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.1423e-06, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(2.6807e-06, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.3587e-06, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.0970e-06, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.8849e-06, device='cuda:0')
# total time is:  798.4284307956696 seconds
# current epoch is:  00
# current loss is:  tensor(1.4165, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0014, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0007, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0002, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(5.4973e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.3479e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(2.6039e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(2.0356e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(1.6727e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.4834e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.3740e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.3004e-05, device='cuda:0')
# total time is:  638.2339460849762 seconds
# current nu_list: 1
# current run: 0
# current epoch is:  00
# current loss is:  tensor(1.7298, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(5.3476e-05, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(1.3384e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(7.1506e-08, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(1.4756e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(1.4121e-08, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(2.3194e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(6.6349e-09, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(4.2393e-09, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(5.1483e-09, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(3.3591e-08, device='cuda:0')
# total time is:  538.7664778232574 seconds
# current epoch is:  00
# current loss is:  tensor(0.0079, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(2.5702e-06, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(4.9831e-07, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(4.1808e-07, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.6995e-07, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.2832e-07, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(2.6587e-07, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(1.7881e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(9.8330e-08, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(5.9512e-08, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(4.6267e-08, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(3.9845e-08, device='cuda:0')
# total time is:  695.4363186359406 seconds
# current epoch is:  00
# current loss is:  tensor(1.9991, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0027, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0006, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(9.9910e-06, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.4930e-06, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(1.2199e-06, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(6.6009e-07, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(4.8846e-07, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(3.6212e-07, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(3.0566e-07, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.6897e-07, device='cuda:0')
# total time is:  506.58718848228455 seconds
# current run: 1
# current epoch is:  00
# current loss is:  tensor(1.8605, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0011, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(2.0758e-05, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(1.6084e-05, device='cuda:0')
# Now epoch number is:11388

# %%
def plot_loss_epoch(loss_record_all, error_record_all,epoch, var_loss, var_error,nu):
    para = nu
    fig = plt.figure()
    # Set subplots size
    fig.set_figheight(15)
    fig.set_figwidth(20)

    ax = fig.add_subplot(2, 1, 1)
    # plot a smooth curve of loss
    ax.plot(np.arange(epoch), loss_record_all[0])
    ax.plot(np.arange(epoch), loss_record_all[1])
    ax.plot(np.arange(epoch), loss_record_all[2])
    # append error bar to the plot 
    ax.errorbar(np.arange(epoch), loss_record_all[0], yerr=var_loss[0], label='vanilla')
    ax.errorbar(np.arange(epoch), loss_record_all[1], yerr=var_loss[1], label='boundary-included')
    ax.errorbar(np.arange(epoch), loss_record_all[2], yerr=var_loss[2], label='initial-included')

    ax.set_xlabel('epoch')
    ax.set_ylabel('Empirical loss')
    ax.set_title("Empirical loss for 1D Burgers' equation, epoch = 30000, nu: {}, lr = 0.0001, data_size = 3000".format(para), fontsize=12)
    ax.set_yscale("log")
    ax.legend()

    ax = fig.add_subplot(2, 1, 2)
    # plot a smooth curve of loss
    ax.plot(np.arange(epoch), error_record_all[0])
    ax.plot(np.arange(epoch), error_record_all[1])
    ax.plot(np.arange(epoch), error_record_all[2])
    # append error bar to the plot
    ax.errorbar(np.arange(epoch), error_record_all[0], yerr=var_error[0], label='vanilla')
    ax.errorbar(np.arange(epoch), error_record_all[1], yerr=var_error[1], label='boundary-included')
    ax.errorbar(np.arange(epoch), error_record_all[2], yerr=var_error[2], label='initial-included')

    ax.set_xlabel('epoch')
    ax.set_ylabel('Fractional error w.r.t true solution')
    ax.set_title("Fractional error w.r.t true solution, epoch = 30000, nu: {}, lr = 0.0001,data_size = 3000".format(para), fontsize=12)
    ax.set_yscale("log")
    ax.legend()

    plt.savefig('loss_epoch,1D, epoch = 30000, nu: {},width=300 ,lr = 0.0001,data_size = 3000.png'.format(para))

# %%
epoch = 30000
import pickle
# layer_width_list = [4,40,200,300,1000,2000,3000]
nu_list = [0.1]
layer_width = 300
print(layer_width)

for i in range(len(nu_list)):
  nu = nu_list[i]
  print("current nu_list: {}".format(nu))
  loss_record_all = [[],[],[]]
  error_record_all = [[],[],[]]
  for i in range(3):
    print("current run: {}".format(i))
    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    data_size = 3000
    x1 = generate_sample_one(data_size//3)
    x2 = generate_sample_two(data_size//3)
    x3 = generate_sample_three(data_size//3)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = False, boundary=False)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=False, boundary=False)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())
    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    # plot_heatmap("venilla",initial=False, boundary=False)
    loss_record_all[0].append(loss_record)
    error_record_all[0].append(error_record)

    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = False, boundary=True)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=False, boundary=True)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())

    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    loss_record_all[1].append(loss_record)
    error_record_all[1].append(error_record)
    # plot_heatmap("boundary-included",initial=False, boundary=True)


    net = Net(input_width,layer_width, layer_depth).to(device)
    initialize_weights(net)
    optimizer = optim.Adam(net.parameters())
    # %%
    loss_record = np.zeros(epoch)
    error_record = np.zeros(epoch)
    time_start = time.time()
    for i in range(epoch):
        # scale_y[i] = float(model(scale_x))
        optimizer.zero_grad()
        loss = loss_function(x1, x2, x3, initial = True, boundary=False)
        loss_record[i] = float(loss)
        loss.backward()
        optimizer.step() 
        error_record[i] = cal_error(test_data, initial=True, boundary=False)
        torch.cuda.empty_cache() # clear memory
        print("Now epoch number is:{}".format(i),end='\r')
        if i % 2500 == 0:
          # y2.append(model(x2))
          print("current epoch is: ", i)
          print("current loss is: ", loss.detach())
    time_end = time.time()
    print('total time is: ', time_end-time_start, 'seconds')
    # plot_heatmap("initial-included",initial=True, boundary=False)
    loss_record_all[2].append(loss_record)
    error_record_all[2].append(error_record)

  with open('1D_burger_loss_record_all_nu={}width=300.pkl'.format(nu), 'wb') as f:
      pickle.dump([loss_record_all,error_record_all], f)

  avg_loss_record = []
  avg_error_record = []
  var_error_record = []
  var_loss_record = []
  for i in range(len(loss_record_all)):
      avg_loss_record.append(np.mean(loss_record_all[i], axis=0))
      avg_error_record.append(np.mean(error_record_all[i], axis=0))
      var_error_record.append(np.var(error_record_all[i], axis=0))
      var_loss_record.append(np.var(loss_record_all[i], axis=0))

  plot_loss_epoch(avg_loss_record, avg_error_record, epoch,var_loss_record, var_error_record, nu)
# Out:
# 300
# current nu_list: 0.1
# current run: 0
# current epoch is:  00
# current loss is:  tensor(1.9533, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(4.9797e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(4.7554e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(3.8399e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(3.3257e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(2.8164e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(2.4185e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(2.0929e-05, device='cuda:0')
# total time is:  925.594673871994 seconds
# current epoch is:  00
# current loss is:  tensor(3.3452, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0003, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0001, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(3.9233e-05, device='cuda:0')
# current epoch is:  125000
# current loss is:  tensor(3.2805e-05, device='cuda:0')
# current epoch is:  150000
# current loss is:  tensor(3.3112e-05, device='cuda:0')
# current epoch is:  175000
# current loss is:  tensor(2.1042e-05, device='cuda:0')
# current epoch is:  200000
# current loss is:  tensor(1.9661e-05, device='cuda:0')
# current epoch is:  225000
# current loss is:  tensor(1.6928e-05, device='cuda:0')
# current epoch is:  250000
# current loss is:  tensor(1.5122e-05, device='cuda:0')
# current epoch is:  275000
# current loss is:  tensor(1.5969e-05, device='cuda:0')
# total time is:  1205.842429637909 seconds
# current epoch is:  00
# current loss is:  tensor(2.5324, device='cuda:0')
# current epoch is:  25000
# current loss is:  tensor(0.0288, device='cuda:0')
# current epoch is:  50000
# current loss is:  tensor(0.0152, device='cuda:0')
# current epoch is:  75000
# current loss is:  tensor(0.0035, device='cuda:0')
# current epoch is:  100000
# current loss is:  tensor(0.0022, device='cuda:0')
# Now epoch number is:11191

# %%
import pickle
with open('1D_burger_loss_record_all_nu=1.pkl', 'rb') as f:
    a = pickle.load(f)
loss_record_all = a[0]
error_record_all = a[1]
avg_loss_record = []
avg_error_record = []

var_error_record = []
var_loss_record = []
for i in range(len(loss_record_all)):
    avg_loss_record.append(np.mean(loss_record_all[i], axis=0))
    avg_error_record.append(np.mean(error_record_all[i], axis=0))
    var_error_record.append(np.var(error_record_all[i], axis=0))
    var_loss_record.append(np.var(loss_record_all[i], axis=0))

plot_loss_epoch(avg_loss_record, avg_error_record, epoch,var_loss_record, var_error_record,1)
